# %%
from iwf.result import Result
from pprint import pprint
url = "https://iwf.sport/results/results-by-events/?event_id=486"
# page = Result()._load_result_page(search_url=url)
# pprint(Result()._scrape_result_info(page))

# %%
pprint(Result().get_results(search_url=url))
# Out:
# [{'birthdate': 'Apr 02, 2003',
#   'bodyweight': '48.88',
#   'category': '49',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '121',
#   'jerk1': '115',
#   'jerk2': '121',
#   'jerk3': <strike>126</strike>,
#   'name': 'PAK Myong Jin',
#   'nation': 'PRK',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '100',
#   'snatch1': '90',
#   'snatch2': '96',
#   'snatch3': '100',
#   'total': '221'},
#  {'birthdate': 'May 11, 2003',
#   'bodyweight': '48.95',
#   'category': '49',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '112',
#   'jerk1': '112',
#   'jerk2': <strike>116</strike>,
#   'jerk3': <strike>116</strike>,
#   'name': 'PAK Kang Song',
#   'nation': 'PRK',
#   'rank': '2',
#   'rank_cj': '2',
#   'rank_sn': '2',
#   'snatch': '85',
#   'snatch1': '81',
#   'snatch2': '83',
#   'snatch3': '85',
#   'total': '197'},
#  {'birthdate': 'Dec 11, 2003',
#   'bodyweight': '48.78',
#   'category': '49',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '100',
#   'jerk1': '95',
#   'jerk2': '100',
#   'jerk3': <strike>113</strike>,
#   'name': 'NGUYEN Van Truong',
#   'nation': 'VIE',
#   'rank': '3',
#   'rank_cj': '3',
#   'rank_sn': '3',
#   'snatch': '75',
#   'snatch1': <strike>75</strike>,
#   'snatch2': '75',
#   'snatch3': <strike>82</strike>,
#   'total': '175'},
#  {'birthdate': 'Jan 10, 2004',
#   'bodyweight': '54.34',
#   'category': '55',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '137',
#   'jerk1': '128',
#   'jerk2': '133',
#   'jerk3': '137',
#   'name': 'DO Tu Tung',
#   'nation': 'VIE',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '109',
#   'snatch1': '100',
#   'snatch2': '103',
#   'snatch3': '109',
#   'total': '246'},
#  {'birthdate': 'Jun 09, 2002',
#   'bodyweight': '54.85',
#   'category': '55',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '134',
#   'jerk1': '125',
#   'jerk2': '130',
#   'jerk3': '134',
#   'name': 'MUN Ik Su',
#   'nation': 'PRK',
#   'rank': '2',
#   'rank_cj': '2',
#   'rank_sn': '2',
#   'snatch': '100',
#   'snatch1': '95',
#   'snatch2': '100',
#   'snatch3': <strike>104</strike>,
#   'total': '234'},
#  {'birthdate': 'Mar 27, 2002',
#   'bodyweight': '54.62',
#   'category': '55',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '126',
#   'jerk1': '123',
#   'jerk2': '126',
#   'jerk3': <strike>128</strike>,
#   'name': 'JANG Wi Song',
#   'nation': 'PRK',
#   'rank': '4',
#   'rank_cj': '4',
#   'rank_sn': '3',
#   'snatch': '100',
#   'snatch1': '93',
#   'snatch2': '98',
#   'snatch3': '100',
#   'total': '226'},
#  {'birthdate': 'Jun 27, 2003',
#   'bodyweight': '54.37',
#   'category': '55',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '130',
#   'jerk1': '123',
#   'jerk2': <strike>130</strike>,
#   'jerk3': '130',
#   'name': 'AUYELKHANOV Ablay',
#   'nation': 'KAZ',
#   'rank': '3',
#   'rank_cj': '3',
#   'rank_sn': '4',
#   'snatch': '97',
#   'snatch1': '93',
#   'snatch2': '97',
#   'snatch3': <strike>100</strike>,
#   'total': '227'},
#  {'birthdate': 'Aug 10, 2004',
#   'bodyweight': '54.74',
#   'category': '55',
#   'gender': 'Men',
#   'group': 'B',
#   'jerk': '108',
#   'jerk1': '108',
#   'jerk2': <strike>112</strike>,
#   'jerk3': <strike>113</strike>,
#   'name': 'YANG Fan-Shun',
#   'nation': 'TPE',
#   'rank': '6',
#   'rank_cj': '6',
#   'rank_sn': '5',
#   'snatch': '95',
#   'snatch1': <strike>92</strike>,
#   'snatch2': '92',
#   'snatch3': '95',
#   'total': '203'},
#  {'birthdate': 'Jun 20, 2002',
#   'bodyweight': '54.57',
#   'category': '55',
#   'gender': 'Men',
#   'group': 'B',
#   'jerk': '115',
#   'jerk1': '108',
#   'jerk2': '112',
#   'jerk3': '115',
#   'name': 'KAO Chih-Lin',
#   'nation': 'TPE',
#   'rank': '5',
#   'rank_cj': '5',
#   'rank_sn': '6',
#   'snatch': '89',
#   'snatch1': '85',
#   'snatch2': '89',
#   'snatch3': <strike>92</strike>,
#   'total': '204'},
#  {'birthdate': 'May 21, 2003',
#   'bodyweight': '60.63',
#   'category': '61',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '153',
#   'jerk1': '147',
#   'jerk2': '150',
#   'jerk3': '153',
#   'name': 'FAATHIR Muhammad',
#   'nation': 'INA',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '119',
#   'snatch1': '116',
#   'snatch2': '119',
#   'snatch3': <strike>122</strike>,
#   'total': '272'},
#  {'birthdate': 'Feb 18, 2002',
#   'bodyweight': '60.56',
#   'category': '61',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '141',
#   'jerk1': '138',
#   'jerk2': <strike>141</strike>,
#   'jerk3': '141',
#   'name': 'BUI Dinh Sang',
#   'nation': 'VIE',
#   'rank': '4',
#   'rank_cj': '4',
#   'rank_sn': '2',
#   'snatch': '116',
#   'snatch1': '116',
#   'snatch2': <strike>120</strike>,
#   'snatch3': <strike>120</strike>,
#   'total': '257'},
#  {'birthdate': 'Jul 08, 2002',
#   'bodyweight': '60.42',
#   'category': '61',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '151',
#   'jerk1': '147',
#   'jerk2': '151',
#   'jerk3': <strike>154</strike>,
#   'name': 'SHIN Rok',
#   'nation': 'KOR',
#   'rank': '2',
#   'rank_cj': '2',
#   'rank_sn': '3',
#   'snatch': '116',
#   'snatch1': '116',
#   'snatch2': <strike>120</strike>,
#   'snatch3': <strike>120</strike>,
#   'total': '267'},
#  {'birthdate': 'May 18, 2002',
#   'bodyweight': '60.89',
#   'category': '61',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '143',
#   'jerk1': '140',
#   'jerk2': '143',
#   'jerk3': <strike>152</strike>,
#   'name': 'AKMOLDA Sairamkez',
#   'nation': 'KAZ',
#   'rank': '3',
#   'rank_cj': '3',
#   'rank_sn': '4',
#   'snatch': '115',
#   'snatch1': '110',
#   'snatch2': '115',
#   'snatch3': <strike>120</strike>,
#   'total': '258'},
#  {'birthdate': 'Jun 06, 2002',
#   'bodyweight': '60.42',
#   'category': '61',
#   'gender': 'Men',
#   'group': 'B',
#   'jerk': '137',
#   'jerk1': '130',
#   'jerk2': '137',
#   'jerk3': <strike>140</strike>,
#   'name': 'LIU Yung Fu',
#   'nation': 'TPE',
#   'rank': '5',
#   'rank_cj': '5',
#   'rank_sn': '5',
#   'snatch': '105',
#   'snatch1': '100',
#   'snatch2': '105',
#   'snatch3': <strike>109</strike>,
#   'total': '242'},
#  {'birthdate': 'Sep 25, 2004',
#   'bodyweight': '58.13',
#   'category': '61',
#   'gender': 'Men',
#   'group': 'B',
#   'jerk': '125',
#   'jerk1': <strike>120</strike>,
#   'jerk2': '120',
#   'jerk3': '125',
#   'name': 'CHO Minjae',
#   'nation': 'KOR',
#   'rank': '6',
#   'rank_cj': '6',
#   'rank_sn': '6',
#   'snatch': '95',
#   'snatch1': '90',
#   'snatch2': '95',
#   'snatch3': <strike>100</strike>,
#   'total': '220'},
#  {'birthdate': 'Apr 05, 2002',
#   'bodyweight': '55.55',
#   'category': '61',
#   'gender': 'Men',
#   'group': 'B',
#   'jerk': '120',
#   'jerk1': '115',
#   'jerk2': '120',
#   'jerk3': <strike>123</strike>,
#   'name': 'BABAMURADOV Ali',
#   'nation': 'TKM',
#   'rank': '7',
#   'rank_cj': '7',
#   'rank_sn': '7',
#   'snatch': '95',
#   'snatch1': <strike>95</strike>,
#   'snatch2': <strike>95</strike>,
#   'snatch3': '95',
#   'total': '215'},
#  {'birthdate': 'Apr 23, 2002',
#   'bodyweight': '59.73',
#   'category': '61',
#   'gender': 'Men',
#   'group': 'B',
#   'jerk': '105',
#   'jerk1': '100',
#   'jerk2': '105',
#   'jerk3': <strike>110</strike>,
#   'name': 'ULAANTSETSEG Amarbayar',
#   'nation': 'MGL',
#   'rank': '8',
#   'rank_cj': '8',
#   'rank_sn': '8',
#   'snatch': '86',
#   'snatch1': '77',
#   'snatch2': '82',
#   'snatch3': '86',
#   'total': '191'},
#  {'birthdate': 'Oct 26, 2002',
#   'bodyweight': '65.92',
#   'category': '67',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '165',
#   'jerk1': <strike>161</strike>,
#   'jerk2': '161',
#   'jerk3': '165',
#   'name': 'JEREMY Lalrinnunga',
#   'nation': 'IND',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '134',
#   'snatch1': <strike>131</strike>,
#   'snatch2': '134',
#   'snatch3': <strike>137</strike>,
#   'total': '299'},
#  {'birthdate': 'Jun 17, 2003',
#   'bodyweight': '66.77',
#   'category': '67',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '157',
#   'jerk1': '145',
#   'jerk2': '153',
#   'jerk3': '157',
#   'name': 'JUNIANSYAH Rizki',
#   'nation': 'INA',
#   'rank': '2',
#   'rank_cj': '2',
#   'rank_sn': '2',
#   'snatch': '130',
#   'snatch1': '120',
#   'snatch2': '125',
#   'snatch3': '130',
#   'total': '287'},
#  {'birthdate': 'Dec 04, 2002',
#   'bodyweight': '66.59',
#   'category': '67',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '140',
#   'jerk1': '140',
#   'jerk2': <strike>145</strike>,
#   'jerk3': <strike>145</strike>,
#   'name': 'REYIMOV Bektimur',
#   'nation': 'TKM',
#   'rank': '4',
#   'rank_cj': '4',
#   'rank_sn': '3',
#   'snatch': '121',
#   'snatch1': '118',
#   'snatch2': '121',
#   'snatch3': <strike>124</strike>,
#   'total': '261'},
#  {'birthdate': 'Feb 11, 2003',
#   'bodyweight': '66.98',
#   'category': '67',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '154',
#   'jerk1': '146',
#   'jerk2': '151',
#   'jerk3': '154',
#   'name': 'OLIMOV Khojiakbar',
#   'nation': 'UZB',
#   'rank': '3',
#   'rank_cj': '3',
#   'rank_sn': '4',
#   'snatch': '119',
#   'snatch1': '119',
#   'snatch2': <strike>122</strike>,
#   'snatch3': <strike>123</strike>,
#   'total': '273'},
#  {'birthdate': 'Apr 11, 2003',
#   'bodyweight': '66.98',
#   'category': '67',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '140',
#   'jerk1': <strike>140</strike>,
#   'jerk2': '140',
#   'jerk3': <strike>146</strike>,
#   'name': 'TORAYEV Gaygysyz',
#   'nation': 'TKM',
#   'rank': '5',
#   'rank_cj': '5',
#   'rank_sn': '5',
#   'snatch': '115',
#   'snatch1': '115',
#   'snatch2': <strike>119</strike>,
#   'snatch3': <strike>119</strike>,
#   'total': '255'},
#  {'birthdate': 'Jan 01, 2003',
#   'bodyweight': '66.08',
#   'category': '67',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '132',
#   'jerk1': <strike>130</strike>,
#   'jerk2': <strike>132</strike>,
#   'jerk3': '132',
#   'name': 'ISLAM Md Nayemul',
#   'nation': 'BAN',
#   'rank': '6',
#   'rank_cj': '7',
#   'rank_sn': '6',
#   'snatch': '114',
#   'snatch1': '108',
#   'snatch2': <strike>114</strike>,
#   'snatch3': '114',
#   'total': '246'},
#  {'birthdate': 'Apr 19, 2002',
#   'bodyweight': '66.12',
#   'category': '67',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '140',
#   'jerk1': '130',
#   'jerk2': '135',
#   'jerk3': '140',
#   'name': 'LIANG Ching-Yen',
#   'nation': 'TPE',
#   'rank': '7',
#   'rank_cj': '6',
#   'rank_sn': '7',
#   'snatch': '95',
#   'snatch1': <strike>90</strike>,
#   'snatch2': '90',
#   'snatch3': '95',
#   'total': '235'},
#  {'birthdate': 'Jan 14, 2002',
#   'bodyweight': '72.55',
#   'category': '73',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '156',
#   'jerk1': '156',
#   'jerk2': <strike>161</strike>,
#   'jerk3': <strike>161</strike>,
#   'name': 'PARK Hyeongo',
#   'nation': 'KOR',
#   'rank': '3',
#   'rank_cj': '4',
#   'rank_sn': '1',
#   'snatch': '132',
#   'snatch1': '127',
#   'snatch2': '130',
#   'snatch3': '132',
#   'total': '288'},
#  {'birthdate': 'Feb 09, 2002',
#   'bodyweight': '72.22',
#   'category': '73',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '163',
#   'jerk1': '155',
#   'jerk2': '160',
#   'jerk3': '163',
#   'name': 'NARIMANOV Asadbek',
#   'nation': 'UZB',
#   'rank': '1',
#   'rank_cj': '2',
#   'rank_sn': '2',
#   'snatch': '131',
#   'snatch1': '126',
#   'snatch2': '129',
#   'snatch3': '131',
#   'total': '294'},
#  {'birthdate': 'Jun 05, 2002',
#   'bodyweight': '72.89',
#   'category': '73',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '163',
#   'jerk1': '153',
#   'jerk2': '157',
#   'jerk3': '163',
#   'name': 'TUKHTAEV Ogabek',
#   'nation': 'UZB',
#   'rank': '2',
#   'rank_cj': '1',
#   'rank_sn': '3',
#   'snatch': '129',
#   'snatch1': '124',
#   'snatch2': '126',
#   'snatch3': '129',
#   'total': '292'},
#  {'birthdate': 'Apr 01, 2002',
#   'bodyweight': '72.89',
#   'category': '73',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '158',
#   'jerk1': '150',
#   'jerk2': '155',
#   'jerk3': '158',
#   'name': 'LEIPHRAKPAM Sadananda Singh',
#   'nation': 'IND',
#   'rank': '4',
#   'rank_cj': '3',
#   'rank_sn': '4',
#   'snatch': '125',
#   'snatch1': '121',
#   'snatch2': '125',
#   'snatch3': <strike>127</strike>,
#   'total': '283'},
#  {'birthdate': 'Feb 16, 2002',
#   'bodyweight': '70.28',
#   'category': '73',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '145',
#   'jerk1': '135',
#   'jerk2': '140',
#   'jerk3': '145',
#   'name': 'YANG Wei-Ta',
#   'nation': 'TPE',
#   'rank': '5',
#   'rank_cj': '5',
#   'rank_sn': '5',
#   'snatch': '112',
#   'snatch1': '105',
#   'snatch2': <strike>110</strike>,
#   'snatch3': '112',
#   'total': '257'},
#  {'birthdate': 'Jul 18, 2002',
#   'bodyweight': '79.53',
#   'category': '81',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '166',
#   'jerk1': '156',
#   'jerk2': '160',
#   'jerk3': '166',
#   'name': 'NGUYEN Quoc Toan',
#   'nation': 'VIE',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '141',
#   'snatch1': '130',
#   'snatch2': '136',
#   'snatch3': '141',
#   'total': '307'},
#  {'birthdate': 'Jan 24, 2002',
#   'bodyweight': '80.66',
#   'category': '81',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '165',
#   'jerk1': '165',
#   'jerk2': <strike>183</strike>,
#   'jerk3': <strike>183</strike>,
#   'name': 'SAPI Yessenkeldi',
#   'nation': 'KAZ',
#   'rank': '2',
#   'rank_cj': '2',
#   'rank_sn': '2',
#   'snatch': '125',
#   'snatch1': '125',
#   'snatch2': <strike>130</strike>,
#   'snatch3': <strike>130</strike>,
#   'total': '290'},
#  {'birthdate': 'Mar 17, 2002',
#   'bodyweight': '77.70',
#   'category': '81',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '157',
#   'jerk1': '150',
#   'jerk2': '154',
#   'jerk3': '157',
#   'name': 'BAYRAMGELDIYEV Shageldi',
#   'nation': 'TKM',
#   'rank': '3',
#   'rank_cj': '4',
#   'rank_sn': '3',
#   'snatch': '123',
#   'snatch1': '123',
#   'snatch2': <strike>126</strike>,
#   'snatch3': <strike>126</strike>,
#   'total': '280'},
#  {'birthdate': 'Aug 29, 2004',
#   'bodyweight': '79.73',
#   'category': '81',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '158',
#   'jerk1': '152',
#   'jerk2': '156',
#   'jerk3': '158',
#   'name': 'YOO Donghyun',
#   'nation': 'KOR',
#   'rank': '4',
#   'rank_cj': '3',
#   'rank_sn': '4',
#   'snatch': '122',
#   'snatch1': <strike>120</strike>,
#   'snatch2': <strike>122</strike>,
#   'snatch3': '122',
#   'total': '280'},
#  {'birthdate': 'Nov 06, 2002',
#   'bodyweight': '79.38',
#   'category': '81',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '132',
#   'jerk1': '127',
#   'jerk2': '132',
#   'jerk3': <strike>140</strike>,
#   'name': 'HUNG Yu-Te',
#   'nation': 'TPE',
#   'rank': '5',
#   'rank_cj': '5',
#   'rank_sn': '5',
#   'snatch': '90',
#   'snatch1': '90',
#   'snatch2': <strike>100</strike>,
#   'snatch3': <strike>100</strike>,
#   'total': '222'},
#  {'birthdate': 'Jun 16, 2002',
#   'bodyweight': '88.14',
#   'category': '89',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '175',
#   'jerk1': '170',
#   'jerk2': '175',
#   'jerk3': <strike>177</strike>,
#   'name': 'ALOTHMAN Ali Yousef A',
#   'nation': 'KSA',
#   'rank': '1',
#   'rank_cj': '2',
#   'rank_sn': '1',
#   'snatch': '143',
#   'snatch1': '135',
#   'snatch2': '140',
#   'snatch3': '143',
#   'total': '318'},
#  {'birthdate': 'Mar 03, 2002',
#   'bodyweight': '88.10',
#   'category': '89',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '176',
#   'jerk1': '160',
#   'jerk2': '171',
#   'jerk3': '176',
#   'name': 'VUONG Truong Khoi',
#   'nation': 'VIE',
#   'rank': '2',
#   'rank_cj': '1',
#   'rank_sn': '2',
#   'snatch': '134',
#   'snatch1': '127',
#   'snatch2': '132',
#   'snatch3': '134',
#   'total': '310'},
#  {'birthdate': 'Dec 13, 2002',
#   'bodyweight': '87.60',
#   'category': '89',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '158',
#   'jerk1': '150',
#   'jerk2': '158',
#   'jerk3': '---',
#   'name': 'BANG Bonghyun',
#   'nation': 'KOR',
#   'rank': '3',
#   'rank_cj': '3',
#   'rank_sn': '3',
#   'snatch': '133',
#   'snatch1': '127',
#   'snatch2': <strike>131</strike>,
#   'snatch3': '133',
#   'total': '291'},
#  {'birthdate': 'Jul 29, 2004',
#   'bodyweight': '86.26',
#   'category': '89',
#   'gender': 'Men',
#   'group': 'B',
#   'jerk': '156',
#   'jerk1': '145',
#   'jerk2': '151',
#   'jerk3': '156',
#   'name': 'CHA Byungjun',
#   'nation': 'KOR',
#   'rank': '4',
#   'rank_cj': '5',
#   'rank_sn': '4',
#   'snatch': '126',
#   'snatch1': '120',
#   'snatch2': <strike>125</strike>,
#   'snatch3': '126',
#   'total': '282'},
#  {'birthdate': 'May 06, 2003',
#   'bodyweight': '87.49',
#   'category': '89',
#   'gender': 'Men',
#   'group': 'B',
#   'jerk': '157',
#   'jerk1': '146',
#   'jerk2': '153',
#   'jerk3': '157',
#   'name': 'CHENG Chi Wei',
#   'nation': 'TPE',
#   'rank': '5',
#   'rank_cj': '4',
#   'rank_sn': '5',
#   'snatch': '115',
#   'snatch1': '115',
#   'snatch2': <strike>125</strike>,
#   'snatch3': <strike>125</strike>,
#   'total': '272'},
#  {'birthdate': 'Jun 04, 2002',
#   'bodyweight': '87.82',
#   'category': '89',
#   'gender': 'Men',
#   'group': 'B',
#   'jerk': '155',
#   'jerk1': '145',
#   'jerk2': <strike>155</strike>,
#   'jerk3': '155',
#   'name': 'HU Guang Jin',
#   'nation': 'TPE',
#   'rank': '6',
#   'rank_cj': '6',
#   'rank_sn': '6',
#   'snatch': '110',
#   'snatch1': '105',
#   'snatch2': '110',
#   'snatch3': <strike>116</strike>,
#   'total': '265'},
#  {'birthdate': 'Jan 14, 2004',
#   'bodyweight': '95.15',
#   'category': '96',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '196',
#   'jerk1': '176',
#   'jerk2': '186',
#   'jerk3': '196',
#   'name': 'BEKBOLAT Rakhat',
#   'nation': 'KAZ',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '156',
#   'snatch1': '144',
#   'snatch2': '150',
#   'snatch3': '156',
#   'total': '352'},
#  {'birthdate': 'Nov 04, 2003',
#   'bodyweight': '101.11',
#   'category': '102',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '166',
#   'jerk1': '160',
#   'jerk2': <strike>166</strike>,
#   'jerk3': '166',
#   'name': 'KHAMIDOV Doniyor',
#   'nation': 'UZB',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '136',
#   'snatch1': '130',
#   'snatch2': '136',
#   'snatch3': <strike>140</strike>,
#   'total': '302'},
#  {'birthdate': 'Nov 07, 2003',
#   'bodyweight': '101.41',
#   'category': '102',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '145',
#   'jerk1': '145',
#   'jerk2': <strike>155</strike>,
#   'jerk3': <strike>160</strike>,
#   'name': 'JIANG Shao-Kai',
#   'nation': 'TPE',
#   'rank': '2',
#   'rank_cj': '2',
#   'rank_sn': '2',
#   'snatch': '122',
#   'snatch1': <strike>115</strike>,
#   'snatch2': '115',
#   'snatch3': '122',
#   'total': '267'},
#  {'birthdate': 'Feb 24, 2002',
#   'bodyweight': '113.15',
#   'category': '+102',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '---',
#   'jerk1': <strike>190</strike>,
#   'jerk2': <strike>202</strike>,
#   'jerk3': '---',
#   'name': 'CHA Kang Jin',
#   'nation': 'PRK',
#   'rank': '---',
#   'rank_cj': '---',
#   'rank_sn': '1',
#   'snatch': '157',
#   'snatch1': '152',
#   'snatch2': '157',
#   'snatch3': <strike>160</strike>,
#   'total': '---'},
#  {'birthdate': 'Mar 07, 2002',
#   'bodyweight': '128.60',
#   'category': '+102',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '190',
#   'jerk1': '180',
#   'jerk2': '190',
#   'jerk3': <strike>200</strike>,
#   'name': 'LEE Seungheon',
#   'nation': 'KOR',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '2',
#   'snatch': '156',
#   'snatch1': '146',
#   'snatch2': '151',
#   'snatch3': '156',
#   'total': '346'},
#  {'birthdate': 'May 11, 2002',
#   'bodyweight': '102.10',
#   'category': '+102',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '176',
#   'jerk1': <strike>176</strike>,
#   'jerk2': '176',
#   'jerk3': <strike>180</strike>,
#   'name': 'MIRZABAEV Mirkhosil',
#   'nation': 'UZB',
#   'rank': '2',
#   'rank_cj': '4',
#   'rank_sn': '3',
#   'snatch': '154',
#   'snatch1': '146',
#   'snatch2': '150',
#   'snatch3': '154',
#   'total': '330'},
#  {'birthdate': 'Apr 22, 2003',
#   'bodyweight': '110.35',
#   'category': '+102',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '177',
#   'jerk1': '170',
#   'jerk2': <strike>177</strike>,
#   'jerk3': '177',
#   'name': 'LEE Seunghoon',
#   'nation': 'KOR',
#   'rank': '4',
#   'rank_cj': '3',
#   'rank_sn': '4',
#   'snatch': '147',
#   'snatch1': '135',
#   'snatch2': '142',
#   'snatch3': '147',
#   'total': '324'},
#  {'birthdate': 'May 20, 2002',
#   'bodyweight': '125.42',
#   'category': '+102',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '182',
#   'jerk1': <strike>176</strike>,
#   'jerk2': '178',
#   'jerk3': '182',
#   'name': 'DAYIYEV Atajan',
#   'nation': 'TKM',
#   'rank': '3',
#   'rank_cj': '2',
#   'rank_sn': '5',
#   'snatch': '143',
#   'snatch1': '143',
#   'snatch2': <strike>147</strike>,
#   'snatch3': <strike>148</strike>,
#   'total': '325'},
#  {'birthdate': 'May 09, 2003',
#   'bodyweight': '134.83',
#   'category': '+102',
#   'gender': 'Men',
#   'group': 'A',
#   'jerk': '160',
#   'jerk1': '145',
#   'jerk2': '155',
#   'jerk3': '160',
#   'name': 'WENG Zeng Yu',
#   'nation': 'TPE',
#   'rank': '5',
#   'rank_cj': '5',
#   'rank_sn': '6',
#   'snatch': '130',
#   'snatch1': '115',
#   'snatch2': '125',
#   'snatch3': '130',
#   'total': '290'},
#  {'birthdate': 'Jul 25, 2005',
#   'bodyweight': '39.96',
#   'category': '40',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '72',
#   'jerk1': '65',
#   'jerk2': '68',
#   'jerk3': '72',
#   'name': 'PAK Yong',
#   'nation': 'PRK',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '60',
#   'snatch1': '55',
#   'snatch2': '58',
#   'snatch3': '60',
#   'total': '132'},
#  {'birthdate': 'Jul 13, 2002',
#   'bodyweight': '39.91',
#   'category': '40',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '63',
#   'jerk1': '58',
#   'jerk2': '63',
#   'jerk3': <strike>65</strike>,
#   'name': 'HONG Zi Yu',
#   'nation': 'TPE',
#   'rank': '3',
#   'rank_cj': '3',
#   'rank_sn': '2',
#   'snatch': '52',
#   'snatch1': '48',
#   'snatch2': '52',
#   'snatch3': <strike>54</strike>,
#   'total': '115'},
#  {'birthdate': 'May 06, 2002',
#   'bodyweight': '39.51',
#   'category': '40',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '66',
#   'jerk1': '63',
#   'jerk2': '65',
#   'jerk3': '66',
#   'name': 'MACAWILI Chariz',
#   'nation': 'PHI',
#   'rank': '2',
#   'rank_cj': '2',
#   'rank_sn': '3',
#   'snatch': '50',
#   'snatch1': '50',
#   'snatch2': <strike>53</strike>,
#   'snatch3': <strike>53</strike>,
#   'total': '116'},
#  {'birthdate': 'Dec 22, 2003',
#   'bodyweight': '40.00',
#   'category': '40',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '55',
#   'jerk1': <strike>55</strike>,
#   'jerk2': '55',
#   'jerk3': <strike>58</strike>,
#   'name': 'HSIAO Wei-Chen',
#   'nation': 'TPE',
#   'rank': '4',
#   'rank_cj': '4',
#   'rank_sn': '4',
#   'snatch': '45',
#   'snatch1': <strike>45</strike>,
#   'snatch2': '45',
#   'snatch3': <strike>48</strike>,
#   'total': '100'},
#  {'birthdate': 'Mar 17, 2004',
#   'bodyweight': '45.00',
#   'category': '45',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '95',
#   'jerk1': '91',
#   'jerk2': '95',
#   'jerk3': <strike>99</strike>,
#   'name': 'PAEK Hye Jong',
#   'nation': 'PRK',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '77',
#   'snatch1': '72',
#   'snatch2': '75',
#   'snatch3': '77',
#   'total': '172'},
#  {'birthdate': 'Jan 30, 2004',
#   'bodyweight': '45.00',
#   'category': '45',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '87',
#   'jerk1': <strike>85</strike>,
#   'jerk2': '85',
#   'jerk3': '87',
#   'name': 'PAK Yu Jong',
#   'nation': 'PRK',
#   'rank': '2',
#   'rank_cj': '3',
#   'rank_sn': '2',
#   'snatch': '76',
#   'snatch1': '73',
#   'snatch2': <strike>75</strike>,
#   'snatch3': '76',
#   'total': '163'},
#  {'birthdate': 'Jun 03, 2003',
#   'bodyweight': '44.90',
#   'category': '45',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '86',
#   'jerk1': '83',
#   'jerk2': '86',
#   'jerk3': <strike>90</strike>,
#   'name': 'NGUYEN Thi Thu Trang',
#   'nation': 'VIE',
#   'rank': '3',
#   'rank_cj': '4',
#   'rank_sn': '3',
#   'snatch': '74',
#   'snatch1': <strike>73</strike>,
#   'snatch2': '74',
#   'snatch3': <strike>76</strike>,
#   'total': '160'},
#  {'birthdate': 'Mar 02, 2004',
#   'bodyweight': '44.97',
#   'category': '45',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '88',
#   'jerk1': '85',
#   'jerk2': '88',
#   'jerk3': <strike>92</strike>,
#   'name': 'NGUYEN Thi Thu Hoai',
#   'nation': 'VIE',
#   'rank': '4',
#   'rank_cj': '2',
#   'rank_sn': '4',
#   'snatch': '68',
#   'snatch1': '68',
#   'snatch2': <strike>71</strike>,
#   'snatch3': <strike>71</strike>,
#   'total': '156'},
#  {'birthdate': 'Nov 12, 2004',
#   'bodyweight': '44.99',
#   'category': '45',
#   'gender': 'Women',
#   'group': 'B',
#   'jerk': '74',
#   'jerk1': '67',
#   'jerk2': '70',
#   'jerk3': '74',
#   'name': 'HOJIYEVA Ozoda',
#   'nation': 'UZB',
#   'rank': '5',
#   'rank_cj': '7',
#   'rank_sn': '5',
#   'snatch': '60',
#   'snatch1': '55',
#   'snatch2': '58',
#   'snatch3': '60',
#   'total': '134'},
#  {'birthdate': 'Jul 27, 2002',
#   'bodyweight': '45.00',
#   'category': '45',
#   'gender': 'Women',
#   'group': 'B',
#   'jerk': '76',
#   'jerk1': <strike>72</strike>,
#   'jerk2': '72',
#   'jerk3': '76',
#   'name': 'ZENG Yi Fan',
#   'nation': 'TPE',
#   'rank': '6',
#   'rank_cj': '5',
#   'rank_sn': '6',
#   'snatch': '58',
#   'snatch1': '58',
#   'snatch2': <strike>60</strike>,
#   'snatch3': <strike>60</strike>,
#   'total': '134'},
#  {'birthdate': 'Jan 20, 2004',
#   'bodyweight': '44.66',
#   'category': '45',
#   'gender': 'Women',
#   'group': 'B',
#   'jerk': '70',
#   'jerk1': '67',
#   'jerk2': '70',
#   'jerk3': <strike>73</strike>,
#   'name': 'BUYANDELGER Erdenezul',
#   'nation': 'MGL',
#   'rank': '8',
#   'rank_cj': '8',
#   'rank_sn': '7',
#   'snatch': '56',
#   'snatch1': '53',
#   'snatch2': '56',
#   'snatch3': <strike>59</strike>,
#   'total': '126'},
#  {'birthdate': 'Oct 25, 2005',
#   'bodyweight': '44.77',
#   'category': '45',
#   'gender': 'Women',
#   'group': 'B',
#   'jerk': '76',
#   'jerk1': '70',
#   'jerk2': '73',
#   'jerk3': '76',
#   'name': 'HUANG Yi-Chen',
#   'nation': 'TPE',
#   'rank': '7',
#   'rank_cj': '6',
#   'rank_sn': '8',
#   'snatch': '55',
#   'snatch1': '55',
#   'snatch2': <strike>58</strike>,
#   'snatch3': <strike>58</strike>,
#   'total': '131'},
#  {'birthdate': 'Dec 30, 2004',
#   'bodyweight': '45.00',
#   'category': '45',
#   'gender': 'Women',
#   'group': 'B',
#   'jerk': '68',
#   'jerk1': '68',
#   'jerk2': <strike>71</strike>,
#   'jerk3': <strike>72</strike>,
#   'name': 'SEO Gayoung',
#   'nation': 'KOR',
#   'rank': '9',
#   'rank_cj': '9',
#   'rank_sn': '9',
#   'snatch': '54',
#   'snatch1': '50',
#   'snatch2': '52',
#   'snatch3': '54',
#   'total': '122'},
#  {'birthdate': 'Apr 02, 2002',
#   'bodyweight': '48.56',
#   'category': '49',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '95',
#   'jerk1': <strike>95</strike>,
#   'jerk2': '95',
#   'jerk3': <strike>98</strike>,
#   'name': 'WON Hyon Sim',
#   'nation': 'PRK',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '78',
#   'snatch1': '78',
#   'snatch2': <strike>83</strike>,
#   'snatch3': <strike>83</strike>,
#   'total': '173'},
#  {'birthdate': 'May 13, 2004',
#   'bodyweight': '48.95',
#   'category': '49',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '94',
#   'jerk1': '89',
#   'jerk2': '92',
#   'jerk3': '94',
#   'name': 'ABDULLAEVA Nigora',
#   'nation': 'UZB',
#   'rank': '2',
#   'rank_cj': '2',
#   'rank_sn': '2',
#   'snatch': '76',
#   'snatch1': '73',
#   'snatch2': '76',
#   'snatch3': <strike>79</strike>,
#   'total': '170'},
#  {'birthdate': 'Dec 15, 2003',
#   'bodyweight': '48.42',
#   'category': '49',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '88',
#   'jerk1': '88',
#   'jerk2': <strike>92</strike>,
#   'jerk3': <strike>93</strike>,
#   'name': 'RAMOS Rosegie',
#   'nation': 'PHI',
#   'rank': '4',
#   'rank_cj': '5',
#   'rank_sn': '3',
#   'snatch': '76',
#   'snatch1': '70',
#   'snatch2': '74',
#   'snatch3': '76',
#   'total': '164'},
#  {'birthdate': 'Dec 24, 2002',
#   'bodyweight': '48.87',
#   'category': '49',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '93',
#   'jerk1': '93',
#   'jerk2': <strike>96</strike>,
#   'jerk3': <strike>96</strike>,
#   'name': 'HWANG Ryu Gyong',
#   'nation': 'PRK',
#   'rank': '3',
#   'rank_cj': '3',
#   'rank_sn': '4',
#   'snatch': '75',
#   'snatch1': '73',
#   'snatch2': '75',
#   'snatch3': <strike>77</strike>,
#   'total': '168'},
#  {'birthdate': 'Jan 01, 2002',
#   'bodyweight': '48.72',
#   'category': '49',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '90',
#   'jerk1': '85',
#   'jerk2': '90',
#   'jerk3': <strike>93</strike>,
#   'name': 'VO Thi Ngoc Thanh',
#   'nation': 'VIE',
#   'rank': '5',
#   'rank_cj': '4',
#   'rank_sn': '5',
#   'snatch': '66',
#   'snatch1': <strike>66</strike>,
#   'snatch2': '66',
#   'snatch3': <strike>71</strike>,
#   'total': '156'},
#  {'birthdate': 'Nov 27, 2003',
#   'bodyweight': '48.88',
#   'category': '49',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '78',
#   'jerk1': '75',
#   'jerk2': <strike>78</strike>,
#   'jerk3': '78',
#   'name': 'KIM Hyemin',
#   'nation': 'KOR',
#   'rank': '6',
#   'rank_cj': '6',
#   'rank_sn': '6',
#   'snatch': '63',
#   'snatch1': <strike>60</strike>,
#   'snatch2': '60',
#   'snatch3': '63',
#   'total': '141'},
#  {'birthdate': 'Nov 08, 2003',
#   'bodyweight': '54.98',
#   'category': '55',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '110',
#   'jerk1': '103',
#   'jerk2': '106',
#   'jerk3': '110',
#   'name': 'PAK Jin Hae',
#   'nation': 'PRK',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '87',
#   'snatch1': '80',
#   'snatch2': '85',
#   'snatch3': '87',
#   'total': '197'},
#  {'birthdate': 'Jul 29, 2002',
#   'bodyweight': '54.35',
#   'category': '55',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '100',
#   'jerk1': '95',
#   'jerk2': '100',
#   'jerk3': <strike>104</strike>,
#   'name': 'KLARISA Juliana',
#   'nation': 'INA',
#   'rank': '2',
#   'rank_cj': '2',
#   'rank_sn': '2',
#   'snatch': '75',
#   'snatch1': <strike>74</strike>,
#   'snatch2': <strike>74</strike>,
#   'snatch3': '75',
#   'total': '175'},
#  {'birthdate': 'Aug 26, 2002',
#   'bodyweight': '54.44',
#   'category': '55',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '90',
#   'jerk1': '90',
#   'jerk2': <strike>93</strike>,
#   'jerk3': <strike>93</strike>,
#   'name': 'LEE Yerim',
#   'nation': 'KOR',
#   'rank': '3',
#   'rank_cj': '4',
#   'rank_sn': '3',
#   'snatch': '72',
#   'snatch1': '69',
#   'snatch2': <strike>72</strike>,
#   'snatch3': '72',
#   'total': '162'},
#  {'birthdate': 'Jun 01, 2003',
#   'bodyweight': '53.89',
#   'category': '55',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '92',
#   'jerk1': '85',
#   'jerk2': '88',
#   'jerk3': '92',
#   'name': 'BETUA Gissele Anne',
#   'nation': 'PHI',
#   'rank': '4',
#   'rank_cj': '3',
#   'rank_sn': '4',
#   'snatch': '65',
#   'snatch1': '63',
#   'snatch2': '65',
#   'snatch3': <strike>68</strike>,
#   'total': '157'},
#  {'birthdate': 'Jan 03, 2003',
#   'bodyweight': '49.52',
#   'category': '55',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '85',
#   'jerk1': <strike>80</strike>,
#   'jerk2': '80',
#   'jerk3': '85',
#   'name': 'HSIAO Li-Yun',
#   'nation': 'TPE',
#   'rank': '5',
#   'rank_cj': '5',
#   'rank_sn': '5',
#   'snatch': '63',
#   'snatch1': '60',
#   'snatch2': '63',
#   'snatch3': <strike>66</strike>,
#   'total': '148'},
#  {'birthdate': 'Jul 27, 2003',
#   'bodyweight': '59.00',
#   'category': '59',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '129',
#   'jerk1': '117',
#   'jerk2': '125',
#   'jerk3': '129',
#   'name': 'KIM Il Gyong',
#   'nation': 'PRK',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '99',
#   'snatch1': '93',
#   'snatch2': '97',
#   'snatch3': '99',
#   'total': '228'},
#  {'birthdate': 'May 16, 2002',
#   'bodyweight': '58.14',
#   'category': '59',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '102',
#   'jerk1': '98',
#   'jerk2': '102',
#   'jerk3': <strike>105</strike>,
#   'name': 'ANDRIANI Putri Aulia',
#   'nation': 'INA',
#   'rank': '3',
#   'rank_cj': '3',
#   'rank_sn': '2',
#   'snatch': '84',
#   'snatch1': '80',
#   'snatch2': '84',
#   'snatch3': <strike>86</strike>,
#   'total': '186'},
#  {'birthdate': 'May 11, 2002',
#   'bodyweight': '58.90',
#   'category': '59',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '116',
#   'jerk1': '106',
#   'jerk2': '114',
#   'jerk3': '116',
#   'name': 'PAK Won Gyong',
#   'nation': 'PRK',
#   'rank': '2',
#   'rank_cj': '2',
#   'rank_sn': '3',
#   'snatch': '83',
#   'snatch1': '80',
#   'snatch2': '83',
#   'snatch3': <strike>85</strike>,
#   'total': '199'},
#  {'birthdate': 'Jun 24, 2003',
#   'bodyweight': '58.74',
#   'category': '59',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '96',
#   'jerk1': '96',
#   'jerk2': <strike>101</strike>,
#   'jerk3': <strike>101</strike>,
#   'name': 'YBRAY Gulnur',
#   'nation': 'KAZ',
#   'rank': '4',
#   'rank_cj': '5',
#   'rank_sn': '4',
#   'snatch': '82',
#   'snatch1': '77',
#   'snatch2': '80',
#   'snatch3': '82',
#   'total': '178'},
#  {'birthdate': 'Jul 17, 2002',
#   'bodyweight': '58.69',
#   'category': '59',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '97',
#   'jerk1': <strike>96</strike>,
#   'jerk2': '97',
#   'jerk3': <strike>101</strike>,
#   'name': 'BOLDBAATAR Khongorzul',
#   'nation': 'MGL',
#   'rank': '5',
#   'rank_cj': '4',
#   'rank_sn': '5',
#   'snatch': '75',
#   'snatch1': <strike>74</strike>,
#   'snatch2': '75',
#   'snatch3': <strike>79</strike>,
#   'total': '172'},
#  {'birthdate': 'Jun 13, 2002',
#   'bodyweight': '57.68',
#   'category': '59',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '87',
#   'jerk1': '83',
#   'jerk2': '87',
#   'jerk3': <strike>91</strike>,
#   'name': 'HWANG Sooa',
#   'nation': 'KOR',
#   'rank': '6',
#   'rank_cj': '7',
#   'rank_sn': '6',
#   'snatch': '69',
#   'snatch1': '65',
#   'snatch2': '69',
#   'snatch3': <strike>72</strike>,
#   'total': '156'},
#  {'birthdate': 'Jan 09, 2002',
#   'bodyweight': '52.66',
#   'category': '59',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '87',
#   'jerk1': '87',
#   'jerk2': <strike>91</strike>,
#   'jerk3': <strike>91</strike>,
#   'name': 'LEE Hayeong',
#   'nation': 'KOR',
#   'rank': '7',
#   'rank_cj': '6',
#   'rank_sn': '7',
#   'snatch': '67',
#   'snatch1': '67',
#   'snatch2': <strike>70</strike>,
#   'snatch3': <strike>70</strike>,
#   'total': '154'},
#  {'birthdate': 'Mar 15, 2003',
#   'bodyweight': '61.78',
#   'category': '64',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '122',
#   'jerk1': '122',
#   'jerk2': <strike>127</strike>,
#   'jerk3': <strike>127</strike>,
#   'name': 'RI Suk',
#   'nation': 'PRK',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '96',
#   'snatch1': '90',
#   'snatch2': <strike>96</strike>,
#   'snatch3': '96',
#   'total': '218'},
#  {'birthdate': 'Mar 07, 2002',
#   'bodyweight': '63.14',
#   'category': '64',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '110',
#   'jerk1': <strike>106</strike>,
#   'jerk2': '106',
#   'jerk3': '110',
#   'name': 'KIM Hansol',
#   'nation': 'KOR',
#   'rank': '2',
#   'rank_cj': '2',
#   'rank_sn': '2',
#   'snatch': '82',
#   'snatch1': '78',
#   'snatch2': <strike>82</strike>,
#   'snatch3': '82',
#   'total': '192'},
#  {'birthdate': 'Jun 20, 2002',
#   'bodyweight': '62.22',
#   'category': '64',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '100',
#   'jerk1': <strike>95</strike>,
#   'jerk2': '95',
#   'jerk3': '100',
#   'name': 'LEE Eunhwa',
#   'nation': 'KOR',
#   'rank': '3',
#   'rank_cj': '4',
#   'rank_sn': '3',
#   'snatch': '78',
#   'snatch1': '78',
#   'snatch2': <strike>81</strike>,
#   'snatch3': <strike>82</strike>,
#   'total': '178'},
#  {'birthdate': 'Jan 03, 2002',
#   'bodyweight': '63.68',
#   'category': '64',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '93',
#   'jerk1': <strike>88</strike>,
#   'jerk2': '88',
#   'jerk3': '93',
#   'name': 'HABIBULLOYEVA Fotima',
#   'nation': 'UZB',
#   'rank': '4',
#   'rank_cj': '5',
#   'rank_sn': '4',
#   'snatch': '76',
#   'snatch1': '70',
#   'snatch2': '74',
#   'snatch3': '76',
#   'total': '169'},
#  {'birthdate': 'Aug 06, 2004',
#   'bodyweight': '63.79',
#   'category': '64',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '65',
#   'jerk1': '60',
#   'jerk2': '65',
#   'jerk3': <strike>70</strike>,
#   'name': 'ERDENESUREN Delgertsetseg',
#   'nation': 'MGL',
#   'rank': '5',
#   'rank_cj': '6',
#   'rank_sn': '5',
#   'snatch': '50',
#   'snatch1': '50',
#   'snatch2': <strike>55</strike>,
#   'snatch3': <strike>55</strike>,
#   'total': '115'},
#  {'birthdate': 'Feb 07, 2002',
#   'bodyweight': '62.90',
#   'category': '64',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '105',
#   'jerk1': '97',
#   'jerk2': '101',
#   'jerk3': '105',
#   'name': 'LAM Thi My Le',
#   'nation': 'VIE',
#   'rank': '---',
#   'rank_cj': '3',
#   'rank_sn': '---',
#   'snatch': '---',
#   'snatch1': <strike>83</strike>,
#   'snatch2': <strike>83</strike>,
#   'snatch3': <strike>83</strike>,
#   'total': '---'},
#  {'birthdate': 'Sep 28, 2003',
#   'bodyweight': '69.91',
#   'category': '71',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '118',
#   'jerk1': '110',
#   'jerk2': '114',
#   'jerk3': '118',
#   'name': 'SARNO Vanessa',
#   'nation': 'PHI',
#   'rank': '1',
#   'rank_cj': '2',
#   'rank_sn': '1',
#   'snatch': '91',
#   'snatch1': '87',
#   'snatch2': '91',
#   'snatch3': <strike>94</strike>,
#   'total': '209'},
#  {'birthdate': 'Jan 15, 2004',
#   'bodyweight': '64.96',
#   'category': '71',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '119',
#   'jerk1': '110',
#   'jerk2': <strike>117</strike>,
#   'jerk3': '119',
#   'name': 'UH Ju Hyang',
#   'nation': 'PRK',
#   'rank': '2',
#   'rank_cj': '1',
#   'rank_sn': '2',
#   'snatch': '85',
#   'snatch1': '85',
#   'snatch2': <strike>89</strike>,
#   'snatch3': <strike>89</strike>,
#   'total': '204'},
#  {'birthdate': 'Oct 05, 2005',
#   'bodyweight': '69.58',
#   'category': '71',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '108',
#   'jerk1': '104',
#   'jerk2': '108',
#   'jerk3': <strike>112</strike>,
#   'name': 'SUVONOVA Nigora',
#   'nation': 'UZB',
#   'rank': '3',
#   'rank_cj': '3',
#   'rank_sn': '3',
#   'snatch': '84',
#   'snatch1': '84',
#   'snatch2': <strike>88</strike>,
#   'snatch3': <strike>88</strike>,
#   'total': '192'},
#  {'birthdate': 'Mar 21, 2002',
#   'bodyweight': '70.03',
#   'category': '71',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '100',
#   'jerk1': '95',
#   'jerk2': <strike>100</strike>,
#   'jerk3': '100',
#   'name': 'PARK Dayeon',
#   'nation': 'KOR',
#   'rank': '4',
#   'rank_cj': '5',
#   'rank_sn': '4',
#   'snatch': '83',
#   'snatch1': '78',
#   'snatch2': '81',
#   'snatch3': '83',
#   'total': '183'},
#  {'birthdate': 'Jun 25, 2002',
#   'bodyweight': '70.60',
#   'category': '71',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '101',
#   'jerk1': <strike>98</strike>,
#   'jerk2': '98',
#   'jerk3': '101',
#   'name': 'CHOU Pei-Wen',
#   'nation': 'TPE',
#   'rank': '5',
#   'rank_cj': '4',
#   'rank_sn': '5',
#   'snatch': '80',
#   'snatch1': '75',
#   'snatch2': '80',
#   'snatch3': <strike>82</strike>,
#   'total': '181'},
#  {'birthdate': 'Mar 04, 2002',
#   'bodyweight': '74.83',
#   'category': '76',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '122',
#   'jerk1': <strike>118</strike>,
#   'jerk2': '118',
#   'jerk3': '122',
#   'name': 'JABBOROVA Tursunoy',
#   'nation': 'UZB',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '105',
#   'snatch1': '98',
#   'snatch2': '102',
#   'snatch3': '105',
#   'total': '227'},
#  {'birthdate': 'Mar 23, 2002',
#   'bodyweight': '74.98',
#   'category': '76',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '116',
#   'jerk1': '108',
#   'jerk2': <strike>116</strike>,
#   'jerk3': '116',
#   'name': 'SON Ara',
#   'nation': 'KOR',
#   'rank': '2',
#   'rank_cj': '2',
#   'rank_sn': '2',
#   'snatch': '83',
#   'snatch1': '78',
#   'snatch2': '80',
#   'snatch3': '83',
#   'total': '199'},
#  {'birthdate': 'Jun 08, 2002',
#   'bodyweight': '75.22',
#   'category': '76',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '97',
#   'jerk1': '93',
#   'jerk2': '97',
#   'jerk3': <strike>101</strike>,
#   'name': 'PAN Yu Ru',
#   'nation': 'TPE',
#   'rank': '3',
#   'rank_cj': '3',
#   'rank_sn': '3',
#   'snatch': '79',
#   'snatch1': '73',
#   'snatch2': '77',
#   'snatch3': '79',
#   'total': '176'},
#  {'birthdate': 'May 18, 2002',
#   'bodyweight': '80.38',
#   'category': '81',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '85',
#   'jerk1': <strike>85</strike>,
#   'jerk2': '85',
#   'jerk3': <strike>96</strike>,
#   'name': 'HUNG Yun-Chieh',
#   'nation': 'TPE',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '73',
#   'snatch1': '65',
#   'snatch2': '70',
#   'snatch3': '73',
#   'total': '158'},
#  {'birthdate': 'Mar 12, 2003',
#   'bodyweight': '120.44',
#   'category': '+81',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '145',
#   'jerk1': '145',
#   'jerk2': <strike>151</strike>,
#   'jerk3': <strike>151</strike>,
#   'name': 'PARK Hyejeong',
#   'nation': 'KOR',
#   'rank': '1',
#   'rank_cj': '1',
#   'rank_sn': '1',
#   'snatch': '110',
#   'snatch1': '104',
#   'snatch2': '108',
#   'snatch3': '110',
#   'total': '255'},
#  {'birthdate': 'Jul 08, 2003',
#   'bodyweight': '106.95',
#   'category': '+81',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '132',
#   'jerk1': <strike>132</strike>,
#   'jerk2': '132',
#   'jerk3': <strike>140</strike>,
#   'name': 'SANSYZBAYEVA Aisamal',
#   'nation': 'KAZ',
#   'rank': '2',
#   'rank_cj': '2',
#   'rank_sn': '2',
#   'snatch': '109',
#   'snatch1': '100',
#   'snatch2': '105',
#   'snatch3': '109',
#   'total': '241'},
#  {'birthdate': 'Apr 08, 2004',
#   'bodyweight': '98.86',
#   'category': '+81',
#   'gender': 'Women',
#   'group': 'A',
#   'jerk': '100',
#   'jerk1': '90',
#   'jerk2': '95',
#   'jerk3': '100',
#   'name': 'TANG Jia-Chi',
#   'nation': 'TPE',
#   'rank': '3',
#   'rank_cj': '3',
#   'rank_sn': '3',
#   'snatch': '78',
#   'snatch1': '73',
#   'snatch2': '78',
#   'snatch3': <strike>81</strike>,
#   'total': '178'}]
