# %%
from iwf.result import Result
from pprint import pprint
url = "https://iwf.sport/results/results-by-events/?event_id=486"
page = Result()._load_result_page(search_url=url)
pprint(Result()._scrape_result_info(page))
# Out:
# [{'athlete_url': None,
#   'birthdate': 'Born: Apr 02, 2003',
#   'bodyweight': 'B.weight: 48.88',
#   'category': '49 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'PAK Myong Jin',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '100',
#   'snatch1': '90',
#   'snatch2': '96',
#   'snatch3': '100',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: May 11, 2003',
#   'bodyweight': 'B.weight: 48.95',
#   'category': '49 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'PAK Kang Song',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '85',
#   'snatch1': '81',
#   'snatch2': '83',
#   'snatch3': '85',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Dec 11, 2003',
#   'bodyweight': 'B.weight: 48.78',
#   'category': '49 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'NGUYEN Van Truong',
#   'nation': 'VIE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '75',
#   'snatch1': '75',
#   'snatch2': '75',
#   'snatch3': '82',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jan 10, 2004',
#   'bodyweight': 'B.weight: 54.34',
#   'category': '55 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'DO Tu Tung',
#   'nation': 'VIE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '109',
#   'snatch1': '100',
#   'snatch2': '103',
#   'snatch3': '109',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 09, 2002',
#   'bodyweight': 'B.weight: 54.85',
#   'category': '55 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'MUN Ik Su',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '100',
#   'snatch1': '95',
#   'snatch2': '100',
#   'snatch3': '104',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Mar 27, 2002',
#   'bodyweight': 'B.weight: 54.62',
#   'category': '55 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'JANG Wi Song',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '100',
#   'snatch1': '93',
#   'snatch2': '98',
#   'snatch3': '100',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 27, 2003',
#   'bodyweight': 'B.weight: 54.37',
#   'category': '55 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'AUYELKHANOV Ablay',
#   'nation': 'KAZ',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '97',
#   'snatch1': '93',
#   'snatch2': '97',
#   'snatch3': '100',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Aug 10, 2004',
#   'bodyweight': 'B.weight: 54.74',
#   'category': '55 kg Men',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'YANG Fan-Shun',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '95',
#   'snatch1': '92',
#   'snatch2': '92',
#   'snatch3': '95',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 20, 2002',
#   'bodyweight': 'B.weight: 54.57',
#   'category': '55 kg Men',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'KAO Chih-Lin',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '89',
#   'snatch1': '85',
#   'snatch2': '89',
#   'snatch3': '92',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: May 21, 2003',
#   'bodyweight': 'B.weight: 60.63',
#   'category': '61 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'FAATHIR Muhammad',
#   'nation': 'INA',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '119',
#   'snatch1': '116',
#   'snatch2': '119',
#   'snatch3': '122',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Feb 18, 2002',
#   'bodyweight': 'B.weight: 60.56',
#   'category': '61 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'BUI Dinh Sang',
#   'nation': 'VIE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '116',
#   'snatch1': '116',
#   'snatch2': '120',
#   'snatch3': '120',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jul 08, 2002',
#   'bodyweight': 'B.weight: 60.42',
#   'category': '61 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'SHIN Rok',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '116',
#   'snatch1': '116',
#   'snatch2': '120',
#   'snatch3': '120',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: May 18, 2002',
#   'bodyweight': 'B.weight: 60.89',
#   'category': '61 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'AKMOLDA Sairamkez',
#   'nation': 'KAZ',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '115',
#   'snatch1': '110',
#   'snatch2': '115',
#   'snatch3': '120',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 06, 2002',
#   'bodyweight': 'B.weight: 60.42',
#   'category': '61 kg Men',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'LIU Yung Fu',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '105',
#   'snatch1': '100',
#   'snatch2': '105',
#   'snatch3': '109',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Sep 25, 2004',
#   'bodyweight': 'B.weight: 58.13',
#   'category': '61 kg Men',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'CHO Minjae',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '95',
#   'snatch1': '90',
#   'snatch2': '95',
#   'snatch3': '100',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Apr 05, 2002',
#   'bodyweight': 'B.weight: 55.55',
#   'category': '61 kg Men',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'BABAMURADOV Ali',
#   'nation': 'TKM',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '95',
#   'snatch1': '95',
#   'snatch2': '95',
#   'snatch3': '95',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Apr 23, 2002',
#   'bodyweight': 'B.weight: 59.73',
#   'category': '61 kg Men',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'ULAANTSETSEG Amarbayar',
#   'nation': 'MGL',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '86',
#   'snatch1': '77',
#   'snatch2': '82',
#   'snatch3': '86',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Oct 26, 2002',
#   'bodyweight': 'B.weight: 65.92',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'JEREMY Lalrinnunga',
#   'nation': 'IND',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '134',
#   'snatch1': '131',
#   'snatch2': '134',
#   'snatch3': '137',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 17, 2003',
#   'bodyweight': 'B.weight: 66.77',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'JUNIANSYAH Rizki',
#   'nation': 'INA',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '130',
#   'snatch1': '120',
#   'snatch2': '125',
#   'snatch3': '130',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Dec 04, 2002',
#   'bodyweight': 'B.weight: 66.59',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'REYIMOV Bektimur',
#   'nation': 'TKM',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '121',
#   'snatch1': '118',
#   'snatch2': '121',
#   'snatch3': '124',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Feb 11, 2003',
#   'bodyweight': 'B.weight: 66.98',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'OLIMOV Khojiakbar',
#   'nation': 'UZB',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '119',
#   'snatch1': '119',
#   'snatch2': '122',
#   'snatch3': '123',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Apr 11, 2003',
#   'bodyweight': 'B.weight: 66.98',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'TORAYEV Gaygysyz',
#   'nation': 'TKM',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '115',
#   'snatch1': '115',
#   'snatch2': '119',
#   'snatch3': '119',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jan 01, 2003',
#   'bodyweight': 'B.weight: 66.08',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'ISLAM Md Nayemul',
#   'nation': 'BAN',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '114',
#   'snatch1': '108',
#   'snatch2': '114',
#   'snatch3': '114',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Apr 19, 2002',
#   'bodyweight': 'B.weight: 66.12',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'LIANG Ching-Yen',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '95',
#   'snatch1': '90',
#   'snatch2': '90',
#   'snatch3': '95',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jan 14, 2002',
#   'bodyweight': 'B.weight: 72.55',
#   'category': '73 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'PARK Hyeongo',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '132',
#   'snatch1': '127',
#   'snatch2': '130',
#   'snatch3': '132',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Feb 09, 2002',
#   'bodyweight': 'B.weight: 72.22',
#   'category': '73 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'NARIMANOV Asadbek',
#   'nation': 'UZB',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '131',
#   'snatch1': '126',
#   'snatch2': '129',
#   'snatch3': '131',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 05, 2002',
#   'bodyweight': 'B.weight: 72.89',
#   'category': '73 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'TUKHTAEV Ogabek',
#   'nation': 'UZB',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '129',
#   'snatch1': '124',
#   'snatch2': '126',
#   'snatch3': '129',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Apr 01, 2002',
#   'bodyweight': 'B.weight: 72.89',
#   'category': '73 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'LEIPHRAKPAM Sadananda Singh',
#   'nation': 'IND',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '125',
#   'snatch1': '121',
#   'snatch2': '125',
#   'snatch3': '127',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Feb 16, 2002',
#   'bodyweight': 'B.weight: 70.28',
#   'category': '73 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'YANG Wei-Ta',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '112',
#   'snatch1': '105',
#   'snatch2': '110',
#   'snatch3': '112',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jul 18, 2002',
#   'bodyweight': 'B.weight: 79.53',
#   'category': '81 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'NGUYEN Quoc Toan',
#   'nation': 'VIE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '141',
#   'snatch1': '130',
#   'snatch2': '136',
#   'snatch3': '141',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jan 24, 2002',
#   'bodyweight': 'B.weight: 80.66',
#   'category': '81 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'SAPI Yessenkeldi',
#   'nation': 'KAZ',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '125',
#   'snatch1': '125',
#   'snatch2': '130',
#   'snatch3': '130',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Mar 17, 2002',
#   'bodyweight': 'B.weight: 77.70',
#   'category': '81 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'BAYRAMGELDIYEV Shageldi',
#   'nation': 'TKM',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '123',
#   'snatch1': '123',
#   'snatch2': '126',
#   'snatch3': '126',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Aug 29, 2004',
#   'bodyweight': 'B.weight: 79.73',
#   'category': '81 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'YOO Donghyun',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '122',
#   'snatch1': '120',
#   'snatch2': '122',
#   'snatch3': '122',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Nov 06, 2002',
#   'bodyweight': 'B.weight: 79.38',
#   'category': '81 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'HUNG Yu-Te',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '90',
#   'snatch1': '90',
#   'snatch2': '100',
#   'snatch3': '100',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 16, 2002',
#   'bodyweight': 'B.weight: 88.14',
#   'category': '89 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'ALOTHMAN Ali Yousef A',
#   'nation': 'KSA',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '143',
#   'snatch1': '135',
#   'snatch2': '140',
#   'snatch3': '143',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Mar 03, 2002',
#   'bodyweight': 'B.weight: 88.10',
#   'category': '89 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'VUONG Truong Khoi',
#   'nation': 'VIE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '134',
#   'snatch1': '127',
#   'snatch2': '132',
#   'snatch3': '134',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Dec 13, 2002',
#   'bodyweight': 'B.weight: 87.60',
#   'category': '89 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'BANG Bonghyun',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '133',
#   'snatch1': '127',
#   'snatch2': '131',
#   'snatch3': '133',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jul 29, 2004',
#   'bodyweight': 'B.weight: 86.26',
#   'category': '89 kg Men',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'CHA Byungjun',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '126',
#   'snatch1': '120',
#   'snatch2': '125',
#   'snatch3': '126',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: May 06, 2003',
#   'bodyweight': 'B.weight: 87.49',
#   'category': '89 kg Men',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'CHENG Chi Wei',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '115',
#   'snatch1': '115',
#   'snatch2': '125',
#   'snatch3': '125',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 04, 2002',
#   'bodyweight': 'B.weight: 87.82',
#   'category': '89 kg Men',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'HU Guang Jin',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '110',
#   'snatch1': '105',
#   'snatch2': '110',
#   'snatch3': '116',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jan 14, 2004',
#   'bodyweight': 'B.weight: 95.15',
#   'category': '96 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'BEKBOLAT Rakhat',
#   'nation': 'KAZ',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '156',
#   'snatch1': '144',
#   'snatch2': '150',
#   'snatch3': '156',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Nov 04, 2003',
#   'bodyweight': 'B.weight: 101.11',
#   'category': '102 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'KHAMIDOV Doniyor',
#   'nation': 'UZB',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '136',
#   'snatch1': '130',
#   'snatch2': '136',
#   'snatch3': '140',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Nov 07, 2003',
#   'bodyweight': 'B.weight: 101.41',
#   'category': '102 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'JIANG Shao-Kai',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '122',
#   'snatch1': '115',
#   'snatch2': '115',
#   'snatch3': '122',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Feb 24, 2002',
#   'bodyweight': 'B.weight: 113.15',
#   'category': '+102 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'CHA Kang Jin',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '157',
#   'snatch1': '152',
#   'snatch2': '157',
#   'snatch3': '160',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Mar 07, 2002',
#   'bodyweight': 'B.weight: 128.60',
#   'category': '+102 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'LEE Seungheon',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '156',
#   'snatch1': '146',
#   'snatch2': '151',
#   'snatch3': '156',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: May 11, 2002',
#   'bodyweight': 'B.weight: 102.10',
#   'category': '+102 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'MIRZABAEV Mirkhosil',
#   'nation': 'UZB',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '154',
#   'snatch1': '146',
#   'snatch2': '150',
#   'snatch3': '154',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Apr 22, 2003',
#   'bodyweight': 'B.weight: 110.35',
#   'category': '+102 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'LEE Seunghoon',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '147',
#   'snatch1': '135',
#   'snatch2': '142',
#   'snatch3': '147',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: May 20, 2002',
#   'bodyweight': 'B.weight: 125.42',
#   'category': '+102 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'DAYIYEV Atajan',
#   'nation': 'TKM',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '143',
#   'snatch1': '143',
#   'snatch2': '147',
#   'snatch3': '148',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: May 09, 2003',
#   'bodyweight': 'B.weight: 134.83',
#   'category': '+102 kg Men',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'WENG Zeng Yu',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '130',
#   'snatch1': '115',
#   'snatch2': '125',
#   'snatch3': '130',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jul 25, 2005',
#   'bodyweight': 'B.weight: 39.96',
#   'category': '40 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'PAK Yong',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '60',
#   'snatch1': '55',
#   'snatch2': '58',
#   'snatch3': '60',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jul 13, 2002',
#   'bodyweight': 'B.weight: 39.91',
#   'category': '40 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'HONG Zi Yu',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '52',
#   'snatch1': '48',
#   'snatch2': '52',
#   'snatch3': '54',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: May 06, 2002',
#   'bodyweight': 'B.weight: 39.51',
#   'category': '40 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'MACAWILI Chariz',
#   'nation': 'PHI',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '50',
#   'snatch1': '50',
#   'snatch2': '53',
#   'snatch3': '53',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Dec 22, 2003',
#   'bodyweight': 'B.weight: 40.00',
#   'category': '40 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'HSIAO Wei-Chen',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '45',
#   'snatch1': '45',
#   'snatch2': '45',
#   'snatch3': '48',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Mar 17, 2004',
#   'bodyweight': 'B.weight: 45.00',
#   'category': '45 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'PAEK Hye Jong',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '77',
#   'snatch1': '72',
#   'snatch2': '75',
#   'snatch3': '77',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jan 30, 2004',
#   'bodyweight': 'B.weight: 45.00',
#   'category': '45 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'PAK Yu Jong',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '76',
#   'snatch1': '73',
#   'snatch2': '75',
#   'snatch3': '76',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 03, 2003',
#   'bodyweight': 'B.weight: 44.90',
#   'category': '45 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'NGUYEN Thi Thu Trang',
#   'nation': 'VIE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '74',
#   'snatch1': '73',
#   'snatch2': '74',
#   'snatch3': '76',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Mar 02, 2004',
#   'bodyweight': 'B.weight: 44.97',
#   'category': '45 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'NGUYEN Thi Thu Hoai',
#   'nation': 'VIE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '68',
#   'snatch1': '68',
#   'snatch2': '71',
#   'snatch3': '71',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Nov 12, 2004',
#   'bodyweight': 'B.weight: 44.99',
#   'category': '45 kg Women',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'HOJIYEVA Ozoda',
#   'nation': 'UZB',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '60',
#   'snatch1': '55',
#   'snatch2': '58',
#   'snatch3': '60',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jul 27, 2002',
#   'bodyweight': 'B.weight: 45.00',
#   'category': '45 kg Women',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'ZENG Yi Fan',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '58',
#   'snatch1': '58',
#   'snatch2': '60',
#   'snatch3': '60',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jan 20, 2004',
#   'bodyweight': 'B.weight: 44.66',
#   'category': '45 kg Women',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'BUYANDELGER Erdenezul',
#   'nation': 'MGL',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '56',
#   'snatch1': '53',
#   'snatch2': '56',
#   'snatch3': '59',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Oct 25, 2005',
#   'bodyweight': 'B.weight: 44.77',
#   'category': '45 kg Women',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'HUANG Yi-Chen',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '55',
#   'snatch1': '55',
#   'snatch2': '58',
#   'snatch3': '58',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Dec 30, 2004',
#   'bodyweight': 'B.weight: 45.00',
#   'category': '45 kg Women',
#   'group': 'Group: B',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'SEO Gayoung',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '54',
#   'snatch1': '50',
#   'snatch2': '52',
#   'snatch3': '54',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Apr 02, 2002',
#   'bodyweight': 'B.weight: 48.56',
#   'category': '49 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'WON Hyon Sim',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '78',
#   'snatch1': '78',
#   'snatch2': '83',
#   'snatch3': '83',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: May 13, 2004',
#   'bodyweight': 'B.weight: 48.95',
#   'category': '49 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'ABDULLAEVA Nigora',
#   'nation': 'UZB',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '76',
#   'snatch1': '73',
#   'snatch2': '76',
#   'snatch3': '79',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Dec 15, 2003',
#   'bodyweight': 'B.weight: 48.42',
#   'category': '49 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'RAMOS Rosegie',
#   'nation': 'PHI',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '76',
#   'snatch1': '70',
#   'snatch2': '74',
#   'snatch3': '76',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Dec 24, 2002',
#   'bodyweight': 'B.weight: 48.87',
#   'category': '49 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'HWANG Ryu Gyong',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '75',
#   'snatch1': '73',
#   'snatch2': '75',
#   'snatch3': '77',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jan 01, 2002',
#   'bodyweight': 'B.weight: 48.72',
#   'category': '49 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'VO Thi Ngoc Thanh',
#   'nation': 'VIE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '66',
#   'snatch1': '66',
#   'snatch2': '66',
#   'snatch3': '71',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Nov 27, 2003',
#   'bodyweight': 'B.weight: 48.88',
#   'category': '49 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'KIM Hyemin',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '63',
#   'snatch1': '60',
#   'snatch2': '60',
#   'snatch3': '63',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Nov 08, 2003',
#   'bodyweight': 'B.weight: 54.98',
#   'category': '55 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'PAK Jin Hae',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '87',
#   'snatch1': '80',
#   'snatch2': '85',
#   'snatch3': '87',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jul 29, 2002',
#   'bodyweight': 'B.weight: 54.35',
#   'category': '55 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'KLARISA Juliana',
#   'nation': 'INA',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '75',
#   'snatch1': '74',
#   'snatch2': '74',
#   'snatch3': '75',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Aug 26, 2002',
#   'bodyweight': 'B.weight: 54.44',
#   'category': '55 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'LEE Yerim',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '72',
#   'snatch1': '69',
#   'snatch2': '72',
#   'snatch3': '72',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 01, 2003',
#   'bodyweight': 'B.weight: 53.89',
#   'category': '55 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'BETUA Gissele Anne',
#   'nation': 'PHI',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '65',
#   'snatch1': '63',
#   'snatch2': '65',
#   'snatch3': '68',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jan 03, 2003',
#   'bodyweight': 'B.weight: 49.52',
#   'category': '55 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'HSIAO Li-Yun',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '63',
#   'snatch1': '60',
#   'snatch2': '63',
#   'snatch3': '66',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jul 27, 2003',
#   'bodyweight': 'B.weight: 59.00',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'KIM Il Gyong',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '99',
#   'snatch1': '93',
#   'snatch2': '97',
#   'snatch3': '99',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: May 16, 2002',
#   'bodyweight': 'B.weight: 58.14',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'ANDRIANI Putri Aulia',
#   'nation': 'INA',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '84',
#   'snatch1': '80',
#   'snatch2': '84',
#   'snatch3': '86',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: May 11, 2002',
#   'bodyweight': 'B.weight: 58.90',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'PAK Won Gyong',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '83',
#   'snatch1': '80',
#   'snatch2': '83',
#   'snatch3': '85',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 24, 2003',
#   'bodyweight': 'B.weight: 58.74',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'YBRAY Gulnur',
#   'nation': 'KAZ',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '82',
#   'snatch1': '77',
#   'snatch2': '80',
#   'snatch3': '82',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jul 17, 2002',
#   'bodyweight': 'B.weight: 58.69',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'BOLDBAATAR Khongorzul',
#   'nation': 'MGL',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '75',
#   'snatch1': '74',
#   'snatch2': '75',
#   'snatch3': '79',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 13, 2002',
#   'bodyweight': 'B.weight: 57.68',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'HWANG Sooa',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '69',
#   'snatch1': '65',
#   'snatch2': '69',
#   'snatch3': '72',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jan 09, 2002',
#   'bodyweight': 'B.weight: 52.66',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'LEE Hayeong',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '67',
#   'snatch1': '67',
#   'snatch2': '70',
#   'snatch3': '70',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Mar 15, 2003',
#   'bodyweight': 'B.weight: 61.78',
#   'category': '64 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'RI Suk',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '96',
#   'snatch1': '90',
#   'snatch2': '96',
#   'snatch3': '96',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Mar 07, 2002',
#   'bodyweight': 'B.weight: 63.14',
#   'category': '64 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'KIM Hansol',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '82',
#   'snatch1': '78',
#   'snatch2': '82',
#   'snatch3': '82',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 20, 2002',
#   'bodyweight': 'B.weight: 62.22',
#   'category': '64 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'LEE Eunhwa',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '78',
#   'snatch1': '78',
#   'snatch2': '81',
#   'snatch3': '82',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jan 03, 2002',
#   'bodyweight': 'B.weight: 63.68',
#   'category': '64 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'HABIBULLOYEVA Fotima',
#   'nation': 'UZB',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '76',
#   'snatch1': '70',
#   'snatch2': '74',
#   'snatch3': '76',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Aug 06, 2004',
#   'bodyweight': 'B.weight: 63.79',
#   'category': '64 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'ERDENESUREN Delgertsetseg',
#   'nation': 'MGL',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '50',
#   'snatch1': '50',
#   'snatch2': '55',
#   'snatch3': '55',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Feb 07, 2002',
#   'bodyweight': 'B.weight: 62.90',
#   'category': '64 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'LAM Thi My Le',
#   'nation': 'VIE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '---',
#   'snatch1': '83',
#   'snatch2': '83',
#   'snatch3': '83',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Sep 28, 2003',
#   'bodyweight': 'B.weight: 69.91',
#   'category': '71 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'SARNO Vanessa',
#   'nation': 'PHI',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '91',
#   'snatch1': '87',
#   'snatch2': '91',
#   'snatch3': '94',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jan 15, 2004',
#   'bodyweight': 'B.weight: 64.96',
#   'category': '71 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'UH Ju Hyang',
#   'nation': 'PRK',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '85',
#   'snatch1': '85',
#   'snatch2': '89',
#   'snatch3': '89',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Oct 05, 2005',
#   'bodyweight': 'B.weight: 69.58',
#   'category': '71 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'SUVONOVA Nigora',
#   'nation': 'UZB',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '84',
#   'snatch1': '84',
#   'snatch2': '88',
#   'snatch3': '88',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Mar 21, 2002',
#   'bodyweight': 'B.weight: 70.03',
#   'category': '71 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'PARK Dayeon',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '83',
#   'snatch1': '78',
#   'snatch2': '81',
#   'snatch3': '83',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 25, 2002',
#   'bodyweight': 'B.weight: 70.60',
#   'category': '71 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'CHOU Pei-Wen',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '80',
#   'snatch1': '75',
#   'snatch2': '80',
#   'snatch3': '82',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Mar 04, 2002',
#   'bodyweight': 'B.weight: 74.83',
#   'category': '76 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'JABBOROVA Tursunoy',
#   'nation': 'UZB',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '105',
#   'snatch1': '98',
#   'snatch2': '102',
#   'snatch3': '105',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Mar 23, 2002',
#   'bodyweight': 'B.weight: 74.98',
#   'category': '76 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'SON Ara',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '83',
#   'snatch1': '78',
#   'snatch2': '80',
#   'snatch3': '83',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jun 08, 2002',
#   'bodyweight': 'B.weight: 75.22',
#   'category': '76 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'PAN Yu Ru',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '79',
#   'snatch1': '73',
#   'snatch2': '77',
#   'snatch3': '79',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: May 18, 2002',
#   'bodyweight': 'B.weight: 80.38',
#   'category': '81 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'HUNG Yun-Chieh',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '73',
#   'snatch1': '65',
#   'snatch2': '70',
#   'snatch3': '73',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Mar 12, 2003',
#   'bodyweight': 'B.weight: 120.44',
#   'category': '+81 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'PARK Hyejeong',
#   'nation': 'KOR',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '110',
#   'snatch1': '104',
#   'snatch2': '108',
#   'snatch3': '110',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Jul 08, 2003',
#   'bodyweight': 'B.weight: 106.95',
#   'category': '+81 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'SANSYZBAYEVA Aisamal',
#   'nation': 'KAZ',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '109',
#   'snatch1': '100',
#   'snatch2': '105',
#   'snatch3': '109',
#   'total': None},
#  {'athlete_url': None,
#   'birthdate': 'Born: Apr 08, 2004',
#   'bodyweight': 'B.weight: 98.86',
#   'category': '+81 kg Women',
#   'group': 'Group: A',
#   'jerk': None,
#   'jerk1': None,
#   'jerk2': None,
#   'jerk3': None,
#   'name': 'TANG Jia-Chi',
#   'nation': 'TPE',
#   'rank': None,
#   'rank_cj': None,
#   'rank_sn': None,
#   'snatch': '78',
#   'snatch1': '73',
#   'snatch2': '78',
#   'snatch3': '81',
#   'total': None}]

# %%
# url = "https://iwf.sport/results/results-by-events/?event_id=486"

# %%
# page = Result()._load_result_page(search_url=url)

# %%
# data = {}
# totals = page.find("div", {"id": "men_total"})
# snatch_and_jerks = page.find("div", {"id": "men_snatchjerk"})
# count = 0
# for div_id in page.find_all('div', {'class':'result__container'}):
#     count += 1
#     # for result in div_id.find_all('div'):
#     #     if result.find('h2'):
#             # print(result.findall('h2'))
#     # if div_id.find_all('h2'):
#     #     print(div_id.find_all('h2'))
#     for result in div_id.find_all('div'):
#         # if result.find('h2'): 
#         data["name"] = div_id.find('div', {'class': 'col-7 not__cell__767'})
            
# print(data)
# print(count)

# %%
# from iwf.result import Result
# url = "https://iwf.sport/results/results-by-events/?event_id=486"
# page = Result()._load_result_page(search_url=url)
# print(Result()._scrape_result_info(page))

# %%
            # for c in card.find_all('div',{'class': 'card'}):
            #     # print(c.select('div div a div div.col-7.not__cell__767 p'))
            #     name = c.select('div div a div div.col-7.not__cell__767 p')
            #     if name:
            #         # print(name[0].text.strip())
            
            #         data["name"] = name[0].text.strip()
            #     results.append(data)
            # # data["name"] = card.find('p').text.strip()
            
        #     # print(card.select("div.col-7.not__cell__767"))
        #     # print(card.find('div', {'class': 'col-7 not__cell__767'}).find('p').text.strip())
        #     # for row in card.find_all('div', {'class': 'row no-gutters'}):
        #         # print(row)
        #         # print(a_cl.find('div', {'class': 'col-7 not__cell__767'}).find('p').text.strip())
        #         # data["name"] = a_cl.contents[0].find('div', {'class': 'col-7 not__cell__767'}).find('p').text.strip()
        #         # data["nation"] = a_cl.find('div', {'class': 'col-3 not__cell__767'}).find('p').text.strip()
        #         # data["rank_sn"]  = a_cl.find('div', {'class': 'col-2 not__cell__767'}).find('p').text.strip()
        #         # results.append(data)

        #     # data["birthdate"] = a_cl.find('div', {'class': 'col-5 not__cell__767'}).find('p').text.strip()
        #     # data["bodyweight"] = card.find('div', {'class': 'col-4 not__cell__767'}).find('p').text.strip()
        #     # # data["group"] = card.find('div',{'class':'col-3 not__cell__767'}).parent.find_next_sibling()
        #     # # print(card.find('div',{'class':'col-3 not__cell__767'}).find_next('p'))
        #     # data["snatch1"] = card.find('div', {'class': 'col-3 not__cell__767'}).find('p').text.strip()

        #     # print(card.find_all('div', {'class': 'card'}))

        #     rows = card.find_all('div', {'class': 'card'})
        #     for row in rows:
        #         # print(row)
        #         for r_n in row.contents:
        #             # print(r)
        #             for a in r_n.find('a', {'class': 'col-md-5 title'}):

        #                 data["name"] = a.find_all('col-7 not__cell__767')
