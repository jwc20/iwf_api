# %%
from iwf.result import Result
from pprint import pprint
url = "https://iwf.sport/results/results-by-events/?event_id=486"
page = Result()._load_result_page(search_url=url)
pprint(Result()._scrape_result_info(page))
# Out:
# [{'birthdate': 'Born: Apr 02, 2003',
#   'bodyweight': 'B.weight: 48.88',
#   'category': '49 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 121',
#   'jerk1': '1: 115',
#   'jerk2': '2: 121',
#   'jerk3': '3: 126',
#   'name': 'PAK Myong Jin',
#   'nation': 'PRK',
#   'snatch': '100',
#   'snatch1': <strong>90</strong>,
#   'snatch2': '96',
#   'snatch3': '100',
#   'total': 'Total: 221'},
#  {'birthdate': 'Born: May 11, 2003',
#   'bodyweight': 'B.weight: 48.95',
#   'category': '49 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 112',
#   'jerk1': '1: 112',
#   'jerk2': '2: 116',
#   'jerk3': '3: 116',
#   'name': 'PAK Kang Song',
#   'nation': 'PRK',
#   'snatch': '85',
#   'snatch1': <strong>81</strong>,
#   'snatch2': '83',
#   'snatch3': '85',
#   'total': 'Total: 197'},
#  {'birthdate': 'Born: Dec 11, 2003',
#   'bodyweight': 'B.weight: 48.78',
#   'category': '49 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 100',
#   'jerk1': '1: 95',
#   'jerk2': '2: 100',
#   'jerk3': '3: 113',
#   'name': 'NGUYEN Van Truong',
#   'nation': 'VIE',
#   'snatch': '75',
#   'snatch1': <strong><strike>75</strike></strong>,
#   'snatch2': '75',
#   'snatch3': '82',
#   'total': 'Total: 175'},
#  {'birthdate': 'Born: Jan 10, 2004',
#   'bodyweight': 'B.weight: 54.34',
#   'category': '55 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 137',
#   'jerk1': '1: 128',
#   'jerk2': '2: 133',
#   'jerk3': '3: 137',
#   'name': 'DO Tu Tung',
#   'nation': 'VIE',
#   'snatch': '109',
#   'snatch1': <strong>100</strong>,
#   'snatch2': '103',
#   'snatch3': '109',
#   'total': 'Total: 246'},
#  {'birthdate': 'Born: Jun 09, 2002',
#   'bodyweight': 'B.weight: 54.85',
#   'category': '55 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 134',
#   'jerk1': '1: 125',
#   'jerk2': '2: 130',
#   'jerk3': '3: 134',
#   'name': 'MUN Ik Su',
#   'nation': 'PRK',
#   'snatch': '100',
#   'snatch1': <strong>95</strong>,
#   'snatch2': '100',
#   'snatch3': '104',
#   'total': 'Total: 234'},
#  {'birthdate': 'Born: Mar 27, 2002',
#   'bodyweight': 'B.weight: 54.62',
#   'category': '55 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 126',
#   'jerk1': '1: 123',
#   'jerk2': '2: 126',
#   'jerk3': '3: 128',
#   'name': 'JANG Wi Song',
#   'nation': 'PRK',
#   'snatch': '100',
#   'snatch1': <strong>93</strong>,
#   'snatch2': '98',
#   'snatch3': '100',
#   'total': 'Total: 226'},
#  {'birthdate': 'Born: Jun 27, 2003',
#   'bodyweight': 'B.weight: 54.37',
#   'category': '55 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 130',
#   'jerk1': '1: 123',
#   'jerk2': '2: 130',
#   'jerk3': '3: 130',
#   'name': 'AUYELKHANOV Ablay',
#   'nation': 'KAZ',
#   'snatch': '97',
#   'snatch1': <strong>93</strong>,
#   'snatch2': '97',
#   'snatch3': '100',
#   'total': 'Total: 227'},
#  {'birthdate': 'Born: Aug 10, 2004',
#   'bodyweight': 'B.weight: 54.74',
#   'category': '55 kg Men',
#   'group': 'Group: B',
#   'jerk': 'Total: 108',
#   'jerk1': '1: 108',
#   'jerk2': '2: 112',
#   'jerk3': '3: 113',
#   'name': 'YANG Fan-Shun',
#   'nation': 'TPE',
#   'snatch': '95',
#   'snatch1': <strong><strike>92</strike></strong>,
#   'snatch2': '92',
#   'snatch3': '95',
#   'total': 'Total: 203'},
#  {'birthdate': 'Born: Jun 20, 2002',
#   'bodyweight': 'B.weight: 54.57',
#   'category': '55 kg Men',
#   'group': 'Group: B',
#   'jerk': 'Total: 115',
#   'jerk1': '1: 108',
#   'jerk2': '2: 112',
#   'jerk3': '3: 115',
#   'name': 'KAO Chih-Lin',
#   'nation': 'TPE',
#   'snatch': '89',
#   'snatch1': <strong>85</strong>,
#   'snatch2': '89',
#   'snatch3': '92',
#   'total': 'Total: 204'},
#  {'birthdate': 'Born: May 21, 2003',
#   'bodyweight': 'B.weight: 60.63',
#   'category': '61 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 153',
#   'jerk1': '1: 147',
#   'jerk2': '2: 150',
#   'jerk3': '3: 153',
#   'name': 'FAATHIR Muhammad',
#   'nation': 'INA',
#   'snatch': '119',
#   'snatch1': <strong>116</strong>,
#   'snatch2': '119',
#   'snatch3': '122',
#   'total': 'Total: 272'},
#  {'birthdate': 'Born: Feb 18, 2002',
#   'bodyweight': 'B.weight: 60.56',
#   'category': '61 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 141',
#   'jerk1': '1: 138',
#   'jerk2': '2: 141',
#   'jerk3': '3: 141',
#   'name': 'BUI Dinh Sang',
#   'nation': 'VIE',
#   'snatch': '116',
#   'snatch1': <strong>116</strong>,
#   'snatch2': '120',
#   'snatch3': '120',
#   'total': 'Total: 257'},
#  {'birthdate': 'Born: Jul 08, 2002',
#   'bodyweight': 'B.weight: 60.42',
#   'category': '61 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 151',
#   'jerk1': '1: 147',
#   'jerk2': '2: 151',
#   'jerk3': '3: 154',
#   'name': 'SHIN Rok',
#   'nation': 'KOR',
#   'snatch': '116',
#   'snatch1': <strong>116</strong>,
#   'snatch2': '120',
#   'snatch3': '120',
#   'total': 'Total: 267'},
#  {'birthdate': 'Born: May 18, 2002',
#   'bodyweight': 'B.weight: 60.89',
#   'category': '61 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 143',
#   'jerk1': '1: 140',
#   'jerk2': '2: 143',
#   'jerk3': '3: 152',
#   'name': 'AKMOLDA Sairamkez',
#   'nation': 'KAZ',
#   'snatch': '115',
#   'snatch1': <strong>110</strong>,
#   'snatch2': '115',
#   'snatch3': '120',
#   'total': 'Total: 258'},
#  {'birthdate': 'Born: Jun 06, 2002',
#   'bodyweight': 'B.weight: 60.42',
#   'category': '61 kg Men',
#   'group': 'Group: B',
#   'jerk': 'Total: 137',
#   'jerk1': '1: 130',
#   'jerk2': '2: 137',
#   'jerk3': '3: 140',
#   'name': 'LIU Yung Fu',
#   'nation': 'TPE',
#   'snatch': '105',
#   'snatch1': <strong>100</strong>,
#   'snatch2': '105',
#   'snatch3': '109',
#   'total': 'Total: 242'},
#  {'birthdate': 'Born: Sep 25, 2004',
#   'bodyweight': 'B.weight: 58.13',
#   'category': '61 kg Men',
#   'group': 'Group: B',
#   'jerk': 'Total: 125',
#   'jerk1': '1: 120',
#   'jerk2': '2: 120',
#   'jerk3': '3: 125',
#   'name': 'CHO Minjae',
#   'nation': 'KOR',
#   'snatch': '95',
#   'snatch1': <strong>90</strong>,
#   'snatch2': '95',
#   'snatch3': '100',
#   'total': 'Total: 220'},
#  {'birthdate': 'Born: Apr 05, 2002',
#   'bodyweight': 'B.weight: 55.55',
#   'category': '61 kg Men',
#   'group': 'Group: B',
#   'jerk': 'Total: 120',
#   'jerk1': '1: 115',
#   'jerk2': '2: 120',
#   'jerk3': '3: 123',
#   'name': 'BABAMURADOV Ali',
#   'nation': 'TKM',
#   'snatch': '95',
#   'snatch1': <strong><strike>95</strike></strong>,
#   'snatch2': '95',
#   'snatch3': '95',
#   'total': 'Total: 215'},
#  {'birthdate': 'Born: Apr 23, 2002',
#   'bodyweight': 'B.weight: 59.73',
#   'category': '61 kg Men',
#   'group': 'Group: B',
#   'jerk': 'Total: 105',
#   'jerk1': '1: 100',
#   'jerk2': '2: 105',
#   'jerk3': '3: 110',
#   'name': 'ULAANTSETSEG Amarbayar',
#   'nation': 'MGL',
#   'snatch': '86',
#   'snatch1': <strong>77</strong>,
#   'snatch2': '82',
#   'snatch3': '86',
#   'total': 'Total: 191'},
#  {'birthdate': 'Born: Oct 26, 2002',
#   'bodyweight': 'B.weight: 65.92',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 165',
#   'jerk1': '1: 161',
#   'jerk2': '2: 161',
#   'jerk3': '3: 165',
#   'name': 'JEREMY Lalrinnunga',
#   'nation': 'IND',
#   'snatch': '134',
#   'snatch1': <strong><strike>131</strike></strong>,
#   'snatch2': '134',
#   'snatch3': '137',
#   'total': 'Total: 299'},
#  {'birthdate': 'Born: Jun 17, 2003',
#   'bodyweight': 'B.weight: 66.77',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 157',
#   'jerk1': '1: 145',
#   'jerk2': '2: 153',
#   'jerk3': '3: 157',
#   'name': 'JUNIANSYAH Rizki',
#   'nation': 'INA',
#   'snatch': '130',
#   'snatch1': <strong>120</strong>,
#   'snatch2': '125',
#   'snatch3': '130',
#   'total': 'Total: 287'},
#  {'birthdate': 'Born: Dec 04, 2002',
#   'bodyweight': 'B.weight: 66.59',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 140',
#   'jerk1': '1: 140',
#   'jerk2': '2: 145',
#   'jerk3': '3: 145',
#   'name': 'REYIMOV Bektimur',
#   'nation': 'TKM',
#   'snatch': '121',
#   'snatch1': <strong>118</strong>,
#   'snatch2': '121',
#   'snatch3': '124',
#   'total': 'Total: 261'},
#  {'birthdate': 'Born: Feb 11, 2003',
#   'bodyweight': 'B.weight: 66.98',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 154',
#   'jerk1': '1: 146',
#   'jerk2': '2: 151',
#   'jerk3': '3: 154',
#   'name': 'OLIMOV Khojiakbar',
#   'nation': 'UZB',
#   'snatch': '119',
#   'snatch1': <strong>119</strong>,
#   'snatch2': '122',
#   'snatch3': '123',
#   'total': 'Total: 273'},
#  {'birthdate': 'Born: Apr 11, 2003',
#   'bodyweight': 'B.weight: 66.98',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 140',
#   'jerk1': '1: 140',
#   'jerk2': '2: 140',
#   'jerk3': '3: 146',
#   'name': 'TORAYEV Gaygysyz',
#   'nation': 'TKM',
#   'snatch': '115',
#   'snatch1': <strong>115</strong>,
#   'snatch2': '119',
#   'snatch3': '119',
#   'total': 'Total: 255'},
#  {'birthdate': 'Born: Jan 01, 2003',
#   'bodyweight': 'B.weight: 66.08',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 132',
#   'jerk1': '1: 130',
#   'jerk2': '2: 132',
#   'jerk3': '3: 132',
#   'name': 'ISLAM Md Nayemul',
#   'nation': 'BAN',
#   'snatch': '114',
#   'snatch1': <strong>108</strong>,
#   'snatch2': '114',
#   'snatch3': '114',
#   'total': 'Total: 246'},
#  {'birthdate': 'Born: Apr 19, 2002',
#   'bodyweight': 'B.weight: 66.12',
#   'category': '67 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 140',
#   'jerk1': '1: 130',
#   'jerk2': '2: 135',
#   'jerk3': '3: 140',
#   'name': 'LIANG Ching-Yen',
#   'nation': 'TPE',
#   'snatch': '95',
#   'snatch1': <strong><strike>90</strike></strong>,
#   'snatch2': '90',
#   'snatch3': '95',
#   'total': 'Total: 235'},
#  {'birthdate': 'Born: Jan 14, 2002',
#   'bodyweight': 'B.weight: 72.55',
#   'category': '73 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 156',
#   'jerk1': '1: 156',
#   'jerk2': '2: 161',
#   'jerk3': '3: 161',
#   'name': 'PARK Hyeongo',
#   'nation': 'KOR',
#   'snatch': '132',
#   'snatch1': <strong>127</strong>,
#   'snatch2': '130',
#   'snatch3': '132',
#   'total': 'Total: 288'},
#  {'birthdate': 'Born: Feb 09, 2002',
#   'bodyweight': 'B.weight: 72.22',
#   'category': '73 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 163',
#   'jerk1': '1: 155',
#   'jerk2': '2: 160',
#   'jerk3': '3: 163',
#   'name': 'NARIMANOV Asadbek',
#   'nation': 'UZB',
#   'snatch': '131',
#   'snatch1': <strong>126</strong>,
#   'snatch2': '129',
#   'snatch3': '131',
#   'total': 'Total: 294'},
#  {'birthdate': 'Born: Jun 05, 2002',
#   'bodyweight': 'B.weight: 72.89',
#   'category': '73 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 163',
#   'jerk1': '1: 153',
#   'jerk2': '2: 157',
#   'jerk3': '3: 163',
#   'name': 'TUKHTAEV Ogabek',
#   'nation': 'UZB',
#   'snatch': '129',
#   'snatch1': <strong>124</strong>,
#   'snatch2': '126',
#   'snatch3': '129',
#   'total': 'Total: 292'},
#  {'birthdate': 'Born: Apr 01, 2002',
#   'bodyweight': 'B.weight: 72.89',
#   'category': '73 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 158',
#   'jerk1': '1: 150',
#   'jerk2': '2: 155',
#   'jerk3': '3: 158',
#   'name': 'LEIPHRAKPAM Sadananda Singh',
#   'nation': 'IND',
#   'snatch': '125',
#   'snatch1': <strong>121</strong>,
#   'snatch2': '125',
#   'snatch3': '127',
#   'total': 'Total: 283'},
#  {'birthdate': 'Born: Feb 16, 2002',
#   'bodyweight': 'B.weight: 70.28',
#   'category': '73 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 145',
#   'jerk1': '1: 135',
#   'jerk2': '2: 140',
#   'jerk3': '3: 145',
#   'name': 'YANG Wei-Ta',
#   'nation': 'TPE',
#   'snatch': '112',
#   'snatch1': <strong>105</strong>,
#   'snatch2': '110',
#   'snatch3': '112',
#   'total': 'Total: 257'},
#  {'birthdate': 'Born: Jul 18, 2002',
#   'bodyweight': 'B.weight: 79.53',
#   'category': '81 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 166',
#   'jerk1': '1: 156',
#   'jerk2': '2: 160',
#   'jerk3': '3: 166',
#   'name': 'NGUYEN Quoc Toan',
#   'nation': 'VIE',
#   'snatch': '141',
#   'snatch1': <strong>130</strong>,
#   'snatch2': '136',
#   'snatch3': '141',
#   'total': 'Total: 307'},
#  {'birthdate': 'Born: Jan 24, 2002',
#   'bodyweight': 'B.weight: 80.66',
#   'category': '81 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 165',
#   'jerk1': '1: 165',
#   'jerk2': '2: 183',
#   'jerk3': '3: 183',
#   'name': 'SAPI Yessenkeldi',
#   'nation': 'KAZ',
#   'snatch': '125',
#   'snatch1': <strong>125</strong>,
#   'snatch2': '130',
#   'snatch3': '130',
#   'total': 'Total: 290'},
#  {'birthdate': 'Born: Mar 17, 2002',
#   'bodyweight': 'B.weight: 77.70',
#   'category': '81 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 157',
#   'jerk1': '1: 150',
#   'jerk2': '2: 154',
#   'jerk3': '3: 157',
#   'name': 'BAYRAMGELDIYEV Shageldi',
#   'nation': 'TKM',
#   'snatch': '123',
#   'snatch1': <strong>123</strong>,
#   'snatch2': '126',
#   'snatch3': '126',
#   'total': 'Total: 280'},
#  {'birthdate': 'Born: Aug 29, 2004',
#   'bodyweight': 'B.weight: 79.73',
#   'category': '81 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 158',
#   'jerk1': '1: 152',
#   'jerk2': '2: 156',
#   'jerk3': '3: 158',
#   'name': 'YOO Donghyun',
#   'nation': 'KOR',
#   'snatch': '122',
#   'snatch1': <strong><strike>120</strike></strong>,
#   'snatch2': '122',
#   'snatch3': '122',
#   'total': 'Total: 280'},
#  {'birthdate': 'Born: Nov 06, 2002',
#   'bodyweight': 'B.weight: 79.38',
#   'category': '81 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 132',
#   'jerk1': '1: 127',
#   'jerk2': '2: 132',
#   'jerk3': '3: 140',
#   'name': 'HUNG Yu-Te',
#   'nation': 'TPE',
#   'snatch': '90',
#   'snatch1': <strong>90</strong>,
#   'snatch2': '100',
#   'snatch3': '100',
#   'total': 'Total: 222'},
#  {'birthdate': 'Born: Jun 16, 2002',
#   'bodyweight': 'B.weight: 88.14',
#   'category': '89 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 175',
#   'jerk1': '1: 170',
#   'jerk2': '2: 175',
#   'jerk3': '3: 177',
#   'name': 'ALOTHMAN Ali Yousef A',
#   'nation': 'KSA',
#   'snatch': '143',
#   'snatch1': <strong>135</strong>,
#   'snatch2': '140',
#   'snatch3': '143',
#   'total': 'Total: 318'},
#  {'birthdate': 'Born: Mar 03, 2002',
#   'bodyweight': 'B.weight: 88.10',
#   'category': '89 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 176',
#   'jerk1': '1: 160',
#   'jerk2': '2: 171',
#   'jerk3': '3: 176',
#   'name': 'VUONG Truong Khoi',
#   'nation': 'VIE',
#   'snatch': '134',
#   'snatch1': <strong>127</strong>,
#   'snatch2': '132',
#   'snatch3': '134',
#   'total': 'Total: 310'},
#  {'birthdate': 'Born: Dec 13, 2002',
#   'bodyweight': 'B.weight: 87.60',
#   'category': '89 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 158',
#   'jerk1': '1: 150',
#   'jerk2': '2: 158',
#   'jerk3': '3: ---',
#   'name': 'BANG Bonghyun',
#   'nation': 'KOR',
#   'snatch': '133',
#   'snatch1': <strong>127</strong>,
#   'snatch2': '131',
#   'snatch3': '133',
#   'total': 'Total: 291'},
#  {'birthdate': 'Born: Jul 29, 2004',
#   'bodyweight': 'B.weight: 86.26',
#   'category': '89 kg Men',
#   'group': 'Group: B',
#   'jerk': 'Total: 156',
#   'jerk1': '1: 145',
#   'jerk2': '2: 151',
#   'jerk3': '3: 156',
#   'name': 'CHA Byungjun',
#   'nation': 'KOR',
#   'snatch': '126',
#   'snatch1': <strong>120</strong>,
#   'snatch2': '125',
#   'snatch3': '126',
#   'total': 'Total: 282'},
#  {'birthdate': 'Born: May 06, 2003',
#   'bodyweight': 'B.weight: 87.49',
#   'category': '89 kg Men',
#   'group': 'Group: B',
#   'jerk': 'Total: 157',
#   'jerk1': '1: 146',
#   'jerk2': '2: 153',
#   'jerk3': '3: 157',
#   'name': 'CHENG Chi Wei',
#   'nation': 'TPE',
#   'snatch': '115',
#   'snatch1': <strong>115</strong>,
#   'snatch2': '125',
#   'snatch3': '125',
#   'total': 'Total: 272'},
#  {'birthdate': 'Born: Jun 04, 2002',
#   'bodyweight': 'B.weight: 87.82',
#   'category': '89 kg Men',
#   'group': 'Group: B',
#   'jerk': 'Total: 155',
#   'jerk1': '1: 145',
#   'jerk2': '2: 155',
#   'jerk3': '3: 155',
#   'name': 'HU Guang Jin',
#   'nation': 'TPE',
#   'snatch': '110',
#   'snatch1': <strong>105</strong>,
#   'snatch2': '110',
#   'snatch3': '116',
#   'total': 'Total: 265'},
#  {'birthdate': 'Born: Jan 14, 2004',
#   'bodyweight': 'B.weight: 95.15',
#   'category': '96 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 196',
#   'jerk1': '1: 176',
#   'jerk2': '2: 186',
#   'jerk3': '3: 196',
#   'name': 'BEKBOLAT Rakhat',
#   'nation': 'KAZ',
#   'snatch': '156',
#   'snatch1': <strong>144</strong>,
#   'snatch2': '150',
#   'snatch3': '156',
#   'total': 'Total: 352'},
#  {'birthdate': 'Born: Nov 04, 2003',
#   'bodyweight': 'B.weight: 101.11',
#   'category': '102 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 166',
#   'jerk1': '1: 160',
#   'jerk2': '2: 166',
#   'jerk3': '3: 166',
#   'name': 'KHAMIDOV Doniyor',
#   'nation': 'UZB',
#   'snatch': '136',
#   'snatch1': <strong>130</strong>,
#   'snatch2': '136',
#   'snatch3': '140',
#   'total': 'Total: 302'},
#  {'birthdate': 'Born: Nov 07, 2003',
#   'bodyweight': 'B.weight: 101.41',
#   'category': '102 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 145',
#   'jerk1': '1: 145',
#   'jerk2': '2: 155',
#   'jerk3': '3: 160',
#   'name': 'JIANG Shao-Kai',
#   'nation': 'TPE',
#   'snatch': '122',
#   'snatch1': <strong><strike>115</strike></strong>,
#   'snatch2': '115',
#   'snatch3': '122',
#   'total': 'Total: 267'},
#  {'birthdate': 'Born: Feb 24, 2002',
#   'bodyweight': 'B.weight: 113.15',
#   'category': '+102 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: ---',
#   'jerk1': '1: 190',
#   'jerk2': '2: 202',
#   'jerk3': '3: ---',
#   'name': 'CHA Kang Jin',
#   'nation': 'PRK',
#   'snatch': '157',
#   'snatch1': <strong>152</strong>,
#   'snatch2': '157',
#   'snatch3': '160',
#   'total': 'Total: ---'},
#  {'birthdate': 'Born: Mar 07, 2002',
#   'bodyweight': 'B.weight: 128.60',
#   'category': '+102 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 190',
#   'jerk1': '1: 180',
#   'jerk2': '2: 190',
#   'jerk3': '3: 200',
#   'name': 'LEE Seungheon',
#   'nation': 'KOR',
#   'snatch': '156',
#   'snatch1': <strong>146</strong>,
#   'snatch2': '151',
#   'snatch3': '156',
#   'total': 'Total: 346'},
#  {'birthdate': 'Born: May 11, 2002',
#   'bodyweight': 'B.weight: 102.10',
#   'category': '+102 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 176',
#   'jerk1': '1: 176',
#   'jerk2': '2: 176',
#   'jerk3': '3: 180',
#   'name': 'MIRZABAEV Mirkhosil',
#   'nation': 'UZB',
#   'snatch': '154',
#   'snatch1': <strong>146</strong>,
#   'snatch2': '150',
#   'snatch3': '154',
#   'total': 'Total: 330'},
#  {'birthdate': 'Born: Apr 22, 2003',
#   'bodyweight': 'B.weight: 110.35',
#   'category': '+102 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 177',
#   'jerk1': '1: 170',
#   'jerk2': '2: 177',
#   'jerk3': '3: 177',
#   'name': 'LEE Seunghoon',
#   'nation': 'KOR',
#   'snatch': '147',
#   'snatch1': <strong>135</strong>,
#   'snatch2': '142',
#   'snatch3': '147',
#   'total': 'Total: 324'},
#  {'birthdate': 'Born: May 20, 2002',
#   'bodyweight': 'B.weight: 125.42',
#   'category': '+102 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 182',
#   'jerk1': '1: 176',
#   'jerk2': '2: 178',
#   'jerk3': '3: 182',
#   'name': 'DAYIYEV Atajan',
#   'nation': 'TKM',
#   'snatch': '143',
#   'snatch1': <strong>143</strong>,
#   'snatch2': '147',
#   'snatch3': '148',
#   'total': 'Total: 325'},
#  {'birthdate': 'Born: May 09, 2003',
#   'bodyweight': 'B.weight: 134.83',
#   'category': '+102 kg Men',
#   'group': 'Group: A',
#   'jerk': 'Total: 160',
#   'jerk1': '1: 145',
#   'jerk2': '2: 155',
#   'jerk3': '3: 160',
#   'name': 'WENG Zeng Yu',
#   'nation': 'TPE',
#   'snatch': '130',
#   'snatch1': <strong>115</strong>,
#   'snatch2': '125',
#   'snatch3': '130',
#   'total': 'Total: 290'},
#  {'birthdate': 'Born: Jul 25, 2005',
#   'bodyweight': 'B.weight: 39.96',
#   'category': '40 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 72',
#   'jerk1': '1: 65',
#   'jerk2': '2: 68',
#   'jerk3': '3: 72',
#   'name': 'PAK Yong',
#   'nation': 'PRK',
#   'snatch': '60',
#   'snatch1': <strong>55</strong>,
#   'snatch2': '58',
#   'snatch3': '60',
#   'total': 'Total: 132'},
#  {'birthdate': 'Born: Jul 13, 2002',
#   'bodyweight': 'B.weight: 39.91',
#   'category': '40 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 63',
#   'jerk1': '1: 58',
#   'jerk2': '2: 63',
#   'jerk3': '3: 65',
#   'name': 'HONG Zi Yu',
#   'nation': 'TPE',
#   'snatch': '52',
#   'snatch1': <strong>48</strong>,
#   'snatch2': '52',
#   'snatch3': '54',
#   'total': 'Total: 115'},
#  {'birthdate': 'Born: May 06, 2002',
#   'bodyweight': 'B.weight: 39.51',
#   'category': '40 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 66',
#   'jerk1': '1: 63',
#   'jerk2': '2: 65',
#   'jerk3': '3: 66',
#   'name': 'MACAWILI Chariz',
#   'nation': 'PHI',
#   'snatch': '50',
#   'snatch1': <strong>50</strong>,
#   'snatch2': '53',
#   'snatch3': '53',
#   'total': 'Total: 116'},
#  {'birthdate': 'Born: Dec 22, 2003',
#   'bodyweight': 'B.weight: 40.00',
#   'category': '40 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 55',
#   'jerk1': '1: 55',
#   'jerk2': '2: 55',
#   'jerk3': '3: 58',
#   'name': 'HSIAO Wei-Chen',
#   'nation': 'TPE',
#   'snatch': '45',
#   'snatch1': <strong><strike>45</strike></strong>,
#   'snatch2': '45',
#   'snatch3': '48',
#   'total': 'Total: 100'},
#  {'birthdate': 'Born: Mar 17, 2004',
#   'bodyweight': 'B.weight: 45.00',
#   'category': '45 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 95',
#   'jerk1': '1: 91',
#   'jerk2': '2: 95',
#   'jerk3': '3: 99',
#   'name': 'PAEK Hye Jong',
#   'nation': 'PRK',
#   'snatch': '77',
#   'snatch1': <strong>72</strong>,
#   'snatch2': '75',
#   'snatch3': '77',
#   'total': 'Total: 172'},
#  {'birthdate': 'Born: Jan 30, 2004',
#   'bodyweight': 'B.weight: 45.00',
#   'category': '45 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 87',
#   'jerk1': '1: 85',
#   'jerk2': '2: 85',
#   'jerk3': '3: 87',
#   'name': 'PAK Yu Jong',
#   'nation': 'PRK',
#   'snatch': '76',
#   'snatch1': <strong>73</strong>,
#   'snatch2': '75',
#   'snatch3': '76',
#   'total': 'Total: 163'},
#  {'birthdate': 'Born: Jun 03, 2003',
#   'bodyweight': 'B.weight: 44.90',
#   'category': '45 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 86',
#   'jerk1': '1: 83',
#   'jerk2': '2: 86',
#   'jerk3': '3: 90',
#   'name': 'NGUYEN Thi Thu Trang',
#   'nation': 'VIE',
#   'snatch': '74',
#   'snatch1': <strong><strike>73</strike></strong>,
#   'snatch2': '74',
#   'snatch3': '76',
#   'total': 'Total: 160'},
#  {'birthdate': 'Born: Mar 02, 2004',
#   'bodyweight': 'B.weight: 44.97',
#   'category': '45 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 88',
#   'jerk1': '1: 85',
#   'jerk2': '2: 88',
#   'jerk3': '3: 92',
#   'name': 'NGUYEN Thi Thu Hoai',
#   'nation': 'VIE',
#   'snatch': '68',
#   'snatch1': <strong>68</strong>,
#   'snatch2': '71',
#   'snatch3': '71',
#   'total': 'Total: 156'},
#  {'birthdate': 'Born: Nov 12, 2004',
#   'bodyweight': 'B.weight: 44.99',
#   'category': '45 kg Women',
#   'group': 'Group: B',
#   'jerk': 'Total: 74',
#   'jerk1': '1: 67',
#   'jerk2': '2: 70',
#   'jerk3': '3: 74',
#   'name': 'HOJIYEVA Ozoda',
#   'nation': 'UZB',
#   'snatch': '60',
#   'snatch1': <strong>55</strong>,
#   'snatch2': '58',
#   'snatch3': '60',
#   'total': 'Total: 134'},
#  {'birthdate': 'Born: Jul 27, 2002',
#   'bodyweight': 'B.weight: 45.00',
#   'category': '45 kg Women',
#   'group': 'Group: B',
#   'jerk': 'Total: 76',
#   'jerk1': '1: 72',
#   'jerk2': '2: 72',
#   'jerk3': '3: 76',
#   'name': 'ZENG Yi Fan',
#   'nation': 'TPE',
#   'snatch': '58',
#   'snatch1': <strong>58</strong>,
#   'snatch2': '60',
#   'snatch3': '60',
#   'total': 'Total: 134'},
#  {'birthdate': 'Born: Jan 20, 2004',
#   'bodyweight': 'B.weight: 44.66',
#   'category': '45 kg Women',
#   'group': 'Group: B',
#   'jerk': 'Total: 70',
#   'jerk1': '1: 67',
#   'jerk2': '2: 70',
#   'jerk3': '3: 73',
#   'name': 'BUYANDELGER Erdenezul',
#   'nation': 'MGL',
#   'snatch': '56',
#   'snatch1': <strong>53</strong>,
#   'snatch2': '56',
#   'snatch3': '59',
#   'total': 'Total: 126'},
#  {'birthdate': 'Born: Oct 25, 2005',
#   'bodyweight': 'B.weight: 44.77',
#   'category': '45 kg Women',
#   'group': 'Group: B',
#   'jerk': 'Total: 76',
#   'jerk1': '1: 70',
#   'jerk2': '2: 73',
#   'jerk3': '3: 76',
#   'name': 'HUANG Yi-Chen',
#   'nation': 'TPE',
#   'snatch': '55',
#   'snatch1': <strong>55</strong>,
#   'snatch2': '58',
#   'snatch3': '58',
#   'total': 'Total: 131'},
#  {'birthdate': 'Born: Dec 30, 2004',
#   'bodyweight': 'B.weight: 45.00',
#   'category': '45 kg Women',
#   'group': 'Group: B',
#   'jerk': 'Total: 68',
#   'jerk1': '1: 68',
#   'jerk2': '2: 71',
#   'jerk3': '3: 72',
#   'name': 'SEO Gayoung',
#   'nation': 'KOR',
#   'snatch': '54',
#   'snatch1': <strong>50</strong>,
#   'snatch2': '52',
#   'snatch3': '54',
#   'total': 'Total: 122'},
#  {'birthdate': 'Born: Apr 02, 2002',
#   'bodyweight': 'B.weight: 48.56',
#   'category': '49 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 95',
#   'jerk1': '1: 95',
#   'jerk2': '2: 95',
#   'jerk3': '3: 98',
#   'name': 'WON Hyon Sim',
#   'nation': 'PRK',
#   'snatch': '78',
#   'snatch1': <strong>78</strong>,
#   'snatch2': '83',
#   'snatch3': '83',
#   'total': 'Total: 173'},
#  {'birthdate': 'Born: May 13, 2004',
#   'bodyweight': 'B.weight: 48.95',
#   'category': '49 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 94',
#   'jerk1': '1: 89',
#   'jerk2': '2: 92',
#   'jerk3': '3: 94',
#   'name': 'ABDULLAEVA Nigora',
#   'nation': 'UZB',
#   'snatch': '76',
#   'snatch1': <strong>73</strong>,
#   'snatch2': '76',
#   'snatch3': '79',
#   'total': 'Total: 170'},
#  {'birthdate': 'Born: Dec 15, 2003',
#   'bodyweight': 'B.weight: 48.42',
#   'category': '49 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 88',
#   'jerk1': '1: 88',
#   'jerk2': '2: 92',
#   'jerk3': '3: 93',
#   'name': 'RAMOS Rosegie',
#   'nation': 'PHI',
#   'snatch': '76',
#   'snatch1': <strong>70</strong>,
#   'snatch2': '74',
#   'snatch3': '76',
#   'total': 'Total: 164'},
#  {'birthdate': 'Born: Dec 24, 2002',
#   'bodyweight': 'B.weight: 48.87',
#   'category': '49 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 93',
#   'jerk1': '1: 93',
#   'jerk2': '2: 96',
#   'jerk3': '3: 96',
#   'name': 'HWANG Ryu Gyong',
#   'nation': 'PRK',
#   'snatch': '75',
#   'snatch1': <strong>73</strong>,
#   'snatch2': '75',
#   'snatch3': '77',
#   'total': 'Total: 168'},
#  {'birthdate': 'Born: Jan 01, 2002',
#   'bodyweight': 'B.weight: 48.72',
#   'category': '49 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 90',
#   'jerk1': '1: 85',
#   'jerk2': '2: 90',
#   'jerk3': '3: 93',
#   'name': 'VO Thi Ngoc Thanh',
#   'nation': 'VIE',
#   'snatch': '66',
#   'snatch1': <strong><strike>66</strike></strong>,
#   'snatch2': '66',
#   'snatch3': '71',
#   'total': 'Total: 156'},
#  {'birthdate': 'Born: Nov 27, 2003',
#   'bodyweight': 'B.weight: 48.88',
#   'category': '49 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 78',
#   'jerk1': '1: 75',
#   'jerk2': '2: 78',
#   'jerk3': '3: 78',
#   'name': 'KIM Hyemin',
#   'nation': 'KOR',
#   'snatch': '63',
#   'snatch1': <strong><strike>60</strike></strong>,
#   'snatch2': '60',
#   'snatch3': '63',
#   'total': 'Total: 141'},
#  {'birthdate': 'Born: Nov 08, 2003',
#   'bodyweight': 'B.weight: 54.98',
#   'category': '55 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 110',
#   'jerk1': '1: 103',
#   'jerk2': '2: 106',
#   'jerk3': '3: 110',
#   'name': 'PAK Jin Hae',
#   'nation': 'PRK',
#   'snatch': '87',
#   'snatch1': <strong>80</strong>,
#   'snatch2': '85',
#   'snatch3': '87',
#   'total': 'Total: 197'},
#  {'birthdate': 'Born: Jul 29, 2002',
#   'bodyweight': 'B.weight: 54.35',
#   'category': '55 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 100',
#   'jerk1': '1: 95',
#   'jerk2': '2: 100',
#   'jerk3': '3: 104',
#   'name': 'KLARISA Juliana',
#   'nation': 'INA',
#   'snatch': '75',
#   'snatch1': <strong><strike>74</strike></strong>,
#   'snatch2': '74',
#   'snatch3': '75',
#   'total': 'Total: 175'},
#  {'birthdate': 'Born: Aug 26, 2002',
#   'bodyweight': 'B.weight: 54.44',
#   'category': '55 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 90',
#   'jerk1': '1: 90',
#   'jerk2': '2: 93',
#   'jerk3': '3: 93',
#   'name': 'LEE Yerim',
#   'nation': 'KOR',
#   'snatch': '72',
#   'snatch1': <strong>69</strong>,
#   'snatch2': '72',
#   'snatch3': '72',
#   'total': 'Total: 162'},
#  {'birthdate': 'Born: Jun 01, 2003',
#   'bodyweight': 'B.weight: 53.89',
#   'category': '55 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 92',
#   'jerk1': '1: 85',
#   'jerk2': '2: 88',
#   'jerk3': '3: 92',
#   'name': 'BETUA Gissele Anne',
#   'nation': 'PHI',
#   'snatch': '65',
#   'snatch1': <strong>63</strong>,
#   'snatch2': '65',
#   'snatch3': '68',
#   'total': 'Total: 157'},
#  {'birthdate': 'Born: Jan 03, 2003',
#   'bodyweight': 'B.weight: 49.52',
#   'category': '55 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 85',
#   'jerk1': '1: 80',
#   'jerk2': '2: 80',
#   'jerk3': '3: 85',
#   'name': 'HSIAO Li-Yun',
#   'nation': 'TPE',
#   'snatch': '63',
#   'snatch1': <strong>60</strong>,
#   'snatch2': '63',
#   'snatch3': '66',
#   'total': 'Total: 148'},
#  {'birthdate': 'Born: Jul 27, 2003',
#   'bodyweight': 'B.weight: 59.00',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 129',
#   'jerk1': '1: 117',
#   'jerk2': '2: 125',
#   'jerk3': '3: 129',
#   'name': 'KIM Il Gyong',
#   'nation': 'PRK',
#   'snatch': '99',
#   'snatch1': <strong>93</strong>,
#   'snatch2': '97',
#   'snatch3': '99',
#   'total': 'Total: 228'},
#  {'birthdate': 'Born: May 16, 2002',
#   'bodyweight': 'B.weight: 58.14',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 102',
#   'jerk1': '1: 98',
#   'jerk2': '2: 102',
#   'jerk3': '3: 105',
#   'name': 'ANDRIANI Putri Aulia',
#   'nation': 'INA',
#   'snatch': '84',
#   'snatch1': <strong>80</strong>,
#   'snatch2': '84',
#   'snatch3': '86',
#   'total': 'Total: 186'},
#  {'birthdate': 'Born: May 11, 2002',
#   'bodyweight': 'B.weight: 58.90',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 116',
#   'jerk1': '1: 106',
#   'jerk2': '2: 114',
#   'jerk3': '3: 116',
#   'name': 'PAK Won Gyong',
#   'nation': 'PRK',
#   'snatch': '83',
#   'snatch1': <strong>80</strong>,
#   'snatch2': '83',
#   'snatch3': '85',
#   'total': 'Total: 199'},
#  {'birthdate': 'Born: Jun 24, 2003',
#   'bodyweight': 'B.weight: 58.74',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 96',
#   'jerk1': '1: 96',
#   'jerk2': '2: 101',
#   'jerk3': '3: 101',
#   'name': 'YBRAY Gulnur',
#   'nation': 'KAZ',
#   'snatch': '82',
#   'snatch1': <strong>77</strong>,
#   'snatch2': '80',
#   'snatch3': '82',
#   'total': 'Total: 178'},
#  {'birthdate': 'Born: Jul 17, 2002',
#   'bodyweight': 'B.weight: 58.69',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 97',
#   'jerk1': '1: 96',
#   'jerk2': '2: 97',
#   'jerk3': '3: 101',
#   'name': 'BOLDBAATAR Khongorzul',
#   'nation': 'MGL',
#   'snatch': '75',
#   'snatch1': <strong><strike>74</strike></strong>,
#   'snatch2': '75',
#   'snatch3': '79',
#   'total': 'Total: 172'},
#  {'birthdate': 'Born: Jun 13, 2002',
#   'bodyweight': 'B.weight: 57.68',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 87',
#   'jerk1': '1: 83',
#   'jerk2': '2: 87',
#   'jerk3': '3: 91',
#   'name': 'HWANG Sooa',
#   'nation': 'KOR',
#   'snatch': '69',
#   'snatch1': <strong>65</strong>,
#   'snatch2': '69',
#   'snatch3': '72',
#   'total': 'Total: 156'},
#  {'birthdate': 'Born: Jan 09, 2002',
#   'bodyweight': 'B.weight: 52.66',
#   'category': '59 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 87',
#   'jerk1': '1: 87',
#   'jerk2': '2: 91',
#   'jerk3': '3: 91',
#   'name': 'LEE Hayeong',
#   'nation': 'KOR',
#   'snatch': '67',
#   'snatch1': <strong>67</strong>,
#   'snatch2': '70',
#   'snatch3': '70',
#   'total': 'Total: 154'},
#  {'birthdate': 'Born: Mar 15, 2003',
#   'bodyweight': 'B.weight: 61.78',
#   'category': '64 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 122',
#   'jerk1': '1: 122',
#   'jerk2': '2: 127',
#   'jerk3': '3: 127',
#   'name': 'RI Suk',
#   'nation': 'PRK',
#   'snatch': '96',
#   'snatch1': <strong>90</strong>,
#   'snatch2': '96',
#   'snatch3': '96',
#   'total': 'Total: 218'},
#  {'birthdate': 'Born: Mar 07, 2002',
#   'bodyweight': 'B.weight: 63.14',
#   'category': '64 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 110',
#   'jerk1': '1: 106',
#   'jerk2': '2: 106',
#   'jerk3': '3: 110',
#   'name': 'KIM Hansol',
#   'nation': 'KOR',
#   'snatch': '82',
#   'snatch1': <strong>78</strong>,
#   'snatch2': '82',
#   'snatch3': '82',
#   'total': 'Total: 192'},
#  {'birthdate': 'Born: Jun 20, 2002',
#   'bodyweight': 'B.weight: 62.22',
#   'category': '64 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 100',
#   'jerk1': '1: 95',
#   'jerk2': '2: 95',
#   'jerk3': '3: 100',
#   'name': 'LEE Eunhwa',
#   'nation': 'KOR',
#   'snatch': '78',
#   'snatch1': <strong>78</strong>,
#   'snatch2': '81',
#   'snatch3': '82',
#   'total': 'Total: 178'},
#  {'birthdate': 'Born: Jan 03, 2002',
#   'bodyweight': 'B.weight: 63.68',
#   'category': '64 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 93',
#   'jerk1': '1: 88',
#   'jerk2': '2: 88',
#   'jerk3': '3: 93',
#   'name': 'HABIBULLOYEVA Fotima',
#   'nation': 'UZB',
#   'snatch': '76',
#   'snatch1': <strong>70</strong>,
#   'snatch2': '74',
#   'snatch3': '76',
#   'total': 'Total: 169'},
#  {'birthdate': 'Born: Aug 06, 2004',
#   'bodyweight': 'B.weight: 63.79',
#   'category': '64 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 65',
#   'jerk1': '1: 60',
#   'jerk2': '2: 65',
#   'jerk3': '3: 70',
#   'name': 'ERDENESUREN Delgertsetseg',
#   'nation': 'MGL',
#   'snatch': '50',
#   'snatch1': <strong>50</strong>,
#   'snatch2': '55',
#   'snatch3': '55',
#   'total': 'Total: 115'},
#  {'birthdate': 'Born: Feb 07, 2002',
#   'bodyweight': 'B.weight: 62.90',
#   'category': '64 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 105',
#   'jerk1': '1: 97',
#   'jerk2': '2: 101',
#   'jerk3': '3: 105',
#   'name': 'LAM Thi My Le',
#   'nation': 'VIE',
#   'snatch': '---',
#   'snatch1': <strong><strike>83</strike></strong>,
#   'snatch2': '83',
#   'snatch3': '83',
#   'total': 'Total: ---'},
#  {'birthdate': 'Born: Sep 28, 2003',
#   'bodyweight': 'B.weight: 69.91',
#   'category': '71 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 118',
#   'jerk1': '1: 110',
#   'jerk2': '2: 114',
#   'jerk3': '3: 118',
#   'name': 'SARNO Vanessa',
#   'nation': 'PHI',
#   'snatch': '91',
#   'snatch1': <strong>87</strong>,
#   'snatch2': '91',
#   'snatch3': '94',
#   'total': 'Total: 209'},
#  {'birthdate': 'Born: Jan 15, 2004',
#   'bodyweight': 'B.weight: 64.96',
#   'category': '71 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 119',
#   'jerk1': '1: 110',
#   'jerk2': '2: 117',
#   'jerk3': '3: 119',
#   'name': 'UH Ju Hyang',
#   'nation': 'PRK',
#   'snatch': '85',
#   'snatch1': <strong>85</strong>,
#   'snatch2': '89',
#   'snatch3': '89',
#   'total': 'Total: 204'},
#  {'birthdate': 'Born: Oct 05, 2005',
#   'bodyweight': 'B.weight: 69.58',
#   'category': '71 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 108',
#   'jerk1': '1: 104',
#   'jerk2': '2: 108',
#   'jerk3': '3: 112',
#   'name': 'SUVONOVA Nigora',
#   'nation': 'UZB',
#   'snatch': '84',
#   'snatch1': <strong>84</strong>,
#   'snatch2': '88',
#   'snatch3': '88',
#   'total': 'Total: 192'},
#  {'birthdate': 'Born: Mar 21, 2002',
#   'bodyweight': 'B.weight: 70.03',
#   'category': '71 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 100',
#   'jerk1': '1: 95',
#   'jerk2': '2: 100',
#   'jerk3': '3: 100',
#   'name': 'PARK Dayeon',
#   'nation': 'KOR',
#   'snatch': '83',
#   'snatch1': <strong>78</strong>,
#   'snatch2': '81',
#   'snatch3': '83',
#   'total': 'Total: 183'},
#  {'birthdate': 'Born: Jun 25, 2002',
#   'bodyweight': 'B.weight: 70.60',
#   'category': '71 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 101',
#   'jerk1': '1: 98',
#   'jerk2': '2: 98',
#   'jerk3': '3: 101',
#   'name': 'CHOU Pei-Wen',
#   'nation': 'TPE',
#   'snatch': '80',
#   'snatch1': <strong>75</strong>,
#   'snatch2': '80',
#   'snatch3': '82',
#   'total': 'Total: 181'},
#  {'birthdate': 'Born: Mar 04, 2002',
#   'bodyweight': 'B.weight: 74.83',
#   'category': '76 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 122',
#   'jerk1': '1: 118',
#   'jerk2': '2: 118',
#   'jerk3': '3: 122',
#   'name': 'JABBOROVA Tursunoy',
#   'nation': 'UZB',
#   'snatch': '105',
#   'snatch1': <strong>98</strong>,
#   'snatch2': '102',
#   'snatch3': '105',
#   'total': 'Total: 227'},
#  {'birthdate': 'Born: Mar 23, 2002',
#   'bodyweight': 'B.weight: 74.98',
#   'category': '76 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 116',
#   'jerk1': '1: 108',
#   'jerk2': '2: 116',
#   'jerk3': '3: 116',
#   'name': 'SON Ara',
#   'nation': 'KOR',
#   'snatch': '83',
#   'snatch1': <strong>78</strong>,
#   'snatch2': '80',
#   'snatch3': '83',
#   'total': 'Total: 199'},
#  {'birthdate': 'Born: Jun 08, 2002',
#   'bodyweight': 'B.weight: 75.22',
#   'category': '76 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 97',
#   'jerk1': '1: 93',
#   'jerk2': '2: 97',
#   'jerk3': '3: 101',
#   'name': 'PAN Yu Ru',
#   'nation': 'TPE',
#   'snatch': '79',
#   'snatch1': <strong>73</strong>,
#   'snatch2': '77',
#   'snatch3': '79',
#   'total': 'Total: 176'},
#  {'birthdate': 'Born: May 18, 2002',
#   'bodyweight': 'B.weight: 80.38',
#   'category': '81 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 85',
#   'jerk1': '1: 85',
#   'jerk2': '2: 85',
#   'jerk3': '3: 96',
#   'name': 'HUNG Yun-Chieh',
#   'nation': 'TPE',
#   'snatch': '73',
#   'snatch1': <strong>65</strong>,
#   'snatch2': '70',
#   'snatch3': '73',
#   'total': 'Total: 158'},
#  {'birthdate': 'Born: Mar 12, 2003',
#   'bodyweight': 'B.weight: 120.44',
#   'category': '+81 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 145',
#   'jerk1': '1: 145',
#   'jerk2': '2: 151',
#   'jerk3': '3: 151',
#   'name': 'PARK Hyejeong',
#   'nation': 'KOR',
#   'snatch': '110',
#   'snatch1': <strong>104</strong>,
#   'snatch2': '108',
#   'snatch3': '110',
#   'total': 'Total: 255'},
#  {'birthdate': 'Born: Jul 08, 2003',
#   'bodyweight': 'B.weight: 106.95',
#   'category': '+81 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 132',
#   'jerk1': '1: 132',
#   'jerk2': '2: 132',
#   'jerk3': '3: 140',
#   'name': 'SANSYZBAYEVA Aisamal',
#   'nation': 'KAZ',
#   'snatch': '109',
#   'snatch1': <strong>100</strong>,
#   'snatch2': '105',
#   'snatch3': '109',
#   'total': 'Total: 241'},
#  {'birthdate': 'Born: Apr 08, 2004',
#   'bodyweight': 'B.weight: 98.86',
#   'category': '+81 kg Women',
#   'group': 'Group: A',
#   'jerk': 'Total: 100',
#   'jerk1': '1: 90',
#   'jerk2': '2: 95',
#   'jerk3': '3: 100',
#   'name': 'TANG Jia-Chi',
#   'nation': 'TPE',
#   'snatch': '78',
#   'snatch1': <strong>73</strong>,
#   'snatch2': '78',
#   'snatch3': '81',
#   'total': 'Total: 178'}]
