# %%
import iwf.core as core
# from iwf.helper import _loadNewBodyweightEventsPage
# from iwf.helper import _loadOldBodyweightEventsPage
# from iwf.helper import *

import requests
import time

from bs4 import BeautifulSoup
from urllib.parse import urlencode
from threading import Thread
from queue import Queue

# %%
url = "https://iwf.sport/results/results-by-events/?event_year=2022"

# %%
url = BASE_URL + EVENTS_URL + "/?" + YEAR_URL
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 url = BASE_URL + EVENTS_URL + "/?" + YEAR_URL
#
# NameError: name 'BASE_URL' is not defined

# %%
print(url)
# Out:
# https://iwf.sport/results/results-by-events/?event_year=2022

# %% [markdown]
# ### GET ALL YEARS
# https://iwf.sport/results/results-by-events/

# %%
events_url = BASE_URL + EVENTS_URL
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 events_url = BASE_URL + EVENTS_URL
#
# NameError: name 'BASE_URL' is not defined

# %%
print(events_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 print(events_url)
#
# NameError: name 'events_url' is not defined

# %%
r = requests.get(events_url, headers=HEADERS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 r = requests.get(events_url, headers=HEADERS)
#
# NameError: name 'events_url' is not defined

# %%
# for new bodyweight
html = r.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 # for new bodyweight
# ----> 2 html = r.text
#
# NameError: name 'r' is not defined

# %%
core._loadNewBodyweightEventsPage()
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Results by Events – International Weightlifting Federation</title>
# <meta content="" name="description"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://iwf.sport/feed/rss/" rel="alternate" title="International Weightlifting Federation RSS 0.92 Feed" type="text/xml"/>
# <link href="https://iwf.sport/feed/atom/" rel="alternate" title="International Weightlifting Federation Atom Feed" type="application/atom+xml"/>
# <link href="https://iwf.sport/feed/" rel="alternate" title="International Weightlifting Federation RSS 2.0 Feed" type="application/rss+xml"/>
# <link href="https://iwf.sport/xmlrpc.php" rel="pingback"/>
# <link href="//ssl.p.jwpcdn.com" rel="dns-prefetch"/>
# <link href="//www.google.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://iwf.sport/wp-includes/css/dist/block-library/style.min.css?ver=5.5.9" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://iwf.sport/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=5.2.2" id="contact-form-7-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://iwf.sport/wp-content/themes/iwf2019/assets/css/vendor/bootstrap-grid.min.css?ver=7.5" id="Grid-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://iwf.sport/wp-content/themes/iwf2019/assets/css/vendor/bootstrap-reboot.min.css?ver=7.5" id="Reboot-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://iwf.sport/wp-content/themes/iwf2019/style.css?ver=7.5" id="pandora-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Oswald%3A200%2C300%2C400%2C500%2C600%2C700&amp;display=swap&amp;ver=7.5" id="OswaldFont-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Barlow%3A300%2C400%2C600%2C700&amp;display=swap&amp;ver=7.5" id="BarlowFont-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://iwf.sport/wp-content/themes/iwf2019/assets/css/vendor/swiper.min.css?ver=7.5" id="swiper-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://iwf.sport/wp-content/themes/iwf2019/lib/mmenu/dist/jquery.mmenu.all.css?ver=5.5.9" id="mmenustyle-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://iwf.sport/wp-content/plugins/download-monitor/page-addon/styles.css?ver=5.5.9" id="wp_dlmp_styles-css" media="all" rel="stylesheet" type="text/css"/>
# <script id="jquery-core-js" src="https://iwf.sport/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp" type="text/javascript"></script>
# <script id="jwplayer-js" src="https://ssl.p.jwpcdn.com/6/5/jwplayer.js?ver=5.5.9" type="text/javascript"></script>
# <script id="modernizr-js" src="https://iwf.sport/wp-content/themes/iwf2019/assets/javascript/vendor/modernizr.min.js?ver=7.5" type="text/javascript"></script>
# <link href="https://iwf.sport/wp-json/" rel="https://api.w.org/"/><link href="https://iwf.sport/wp-json/wp/v2/pages/103" rel="alternate" type="application/json"/><link href="https://iwf.sport/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://iwf.sport/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 5.5.9" name="generator"/>
# <link href="https://iwf.sport/results/results-by-events/" rel="canonical"/>
# <link href="https://iwf.sport/?p=103" rel="shortlink"/>
# <link href="https://iwf.sport/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fiwf.sport%2Fresults%2Fresults-by-events%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://iwf.sport/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fiwf.sport%2Fresults%2Fresults-by-events%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <style type="text/css">
# 	.download-info .download-button {
# 		background-image: url(https://iwf.sport/wp-content/plugins/download-monitor/page-addon/downloadbutton.gif);
# 	}
# 	.download-info .more-button {
# 		background-image: url(https://iwf.sport/wp-content/plugins/download-monitor/page-addon/morebutton.gif);
# 	}
# 	</style>
# <script type="text/javascript">jwplayer.defaults = { "ph": 2 };</script>
# <script type="text/javascript">
#             if (typeof(jwp6AddLoadEvent) == 'undefined') {
#                 function jwp6AddLoadEvent(func) {
#                     var oldonload = window.onload;
#                     if (typeof window.onload != 'function') {
#                         window.onload = func;
#                     } else {
#                         window.onload = function() {
#                             if (oldonload) {
#                                 oldonload();
#                             }
#                             func();
#                         }
#                     }
#                 }
#             }
#             </script>
# <link href="https://iwf.sport/wp-content/themes/iwf2019/assets/images/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://iwf.sport/wp-content/themes/iwf2019/assets/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://iwf.sport/wp-content/themes/iwf2019/assets/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://iwf.sport/wp-content/themes/iwf2019/assets/images/favicons/site.webmanifest" rel="manifest"/>
# <link color="#5bbad5" href="https://iwf.sport/wp-content/themes/iwf2019/assets/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#2b5797" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="Results by Events" name="DC.Title"/>
# <meta content="International Weightlifting Federation" name="DC.Publisher"/>
# <meta content="en-US" name="DC.Language" scheme="UTF-8"/>
# <meta content="Results by Events" property="og:title"/>
# <style type="text/css">
# 	span.oe_textdirection { unicode-bidi: bidi-override; direction: rtl; }
# 	span.oe_displaynone { display: none; }
# </style>
# <meta content="Powered by WPBakery Page Builder - drag and drop page builder for WordPress." name="generator"/>
# <noscript><style> .wpb_animate_when_almost_visible { opacity: 1; }</style></noscript> </head>
# <body class="page__template-results-by-events page__results-by-events wpb-js-composer js-comp-ver-6.4.0 vc_responsive" id="page-id-103">
# <img class="img-top-right" src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/bg-top-right.jpg"/>
# <div id="mobile__menu">
# <ul>
# <li>
# <a class="close-button-menu">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close@3x.png 3x"/>
# </a>
# </li>
# <li>
# <a class="first__level" href="#mm-1">
# <span class="number">01 </span>
# IWF/Weightlifting </a>
# <ul>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-35905" id="menu-item-35905"><a href="https://iwf.sport/weightlifting_/aboutus/">About Us</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-30141" id="menu-item-30141"><a>How To</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30140" id="menu-item-30140"><a href="https://iwf.sport/weightlifting_/participants/">Participants</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30142" id="menu-item-30142"><a href="https://iwf.sport/weightlifting_/the-two-lifts/">The Two Lifts</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30143" id="menu-item-30143"><a href="https://iwf.sport/weightlifting_/competition-flow/">Competition flow</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30144" id="menu-item-30144"><a href="https://iwf.sport/weightlifting_/equipment/">Equipment</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30145" id="menu-item-30145"><a href="https://iwf.sport/weightlifting_/loading/">Loading</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30148" id="menu-item-30148"><a href="https://iwf.sport/weightlifting_/rules/">Rules</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30152" id="menu-item-30152"><a href="https://iwf.sport/weightlifting_/athletes-bios/">Athletes / Bios</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30153" id="menu-item-30153"><a href="https://iwf.sport/weightlifting_/history/">History</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30169" id="menu-item-30169"><a href="https://iwf.sport/weightlifting_/hall-of-fame/">Hall of Fame</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30185" id="menu-item-30185"><a href="https://iwf.sport/weightlifting_/licenses/">Licenses</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30188" id="menu-item-30188"><a href="https://iwf.sport/weightlifting_/development/">Development</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-36341" id="menu-item-36341"><a href="https://iwf.sport/safeguarding-athletes/">Safeguarding Athletes</a></li>
# </ul>
# </li>
# <li>
# <a class="first__level" href="#mm-2">
# <span class="number">02 </span>
# News </a>
# <ul>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30086" id="menu-item-30086"><a href="https://iwf.sport/news-and-media/news/">News</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30071" id="menu-item-30071"><a href="https://iwf.sport/weightlifting_/world-weightlifting-magazine/">World Weightlifting Magazine</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-30087" id="menu-item-30087"><a href="https://iwf.sport/category/interviews/">Interviews</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-30088" id="menu-item-30088"><a href="https://iwf.sport/category/anti-doping-news/">Anti-doping news</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-30089" id="menu-item-30089"><a href="https://iwf.sport/category/press-release/">Press Release</a></li>
# </ul>
# </li>
# <li>
# <a class="first__level" href="#mm-3">
# <span class="number">03 </span>
# events </a>
# <ul>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30096" id="menu-item-30096"><a href="https://iwf.sport/events/calendar/">Calendar</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30103" id="menu-item-30103"><a href="https://iwf.sport/events/world-championships/">World Championships</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30105" id="menu-item-30105"><a href="https://iwf.sport/events/olympic-games/">Olympic Games</a></li>
# </ul>
# </li>
# <li>
# <a class="first__level" href="#mm-4">
# <span class="number">04 </span>
# Results </a>
# <ul>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-103 current_page_item menu-item-30114" id="menu-item-30114"><a aria-current="page" href="https://iwf.sport/results/results-by-events/">Results by Events</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30117" id="menu-item-30117"><a href="https://iwf.sport/results/ranking-list/">Ranking list</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30126" id="menu-item-30126"><a href="https://iwf.sport/results/world-records/">World records</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30131" id="menu-item-30131"><a href="https://iwf.sport/results/robi-points/">Robi Points</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-30116" id="menu-item-30116"><a>Old Bodyweight Categories</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30113" id="menu-item-30113"><a href="https://iwf.sport/results/results-by-events/results-by-events-old-bw/">Results By Events</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30122" id="menu-item-30122"><a href="https://iwf.sport/results/ranking-list/ranking-list-old-bw/">Ranking List</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30125" id="menu-item-30125"><a href="https://iwf.sport/results/world-records/world-records-old-bw/">World Records</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <a class="first__level" href="#mm-5">
# <span class="number">05 </span>
# Anti-doping </a>
# <ul>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-35419" id="menu-item-35419"><a href="https://iwf.sport/anti-doping/report-doping-2/">Introduction to anti-doping</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-35430" id="menu-item-35430"><a href="https://iwf.sport/anti-doping/reanalysis-2/">Doping Control</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-35438" id="menu-item-35438"><a href="https://iwf.sport/anti-doping/consequences-of-doping/">Consequences of Doping</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30189" id="menu-item-30189"><a href="https://iwf.sport/anti-doping/whereabouts-irtp/">IRTP / Whereabouts</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30192" id="menu-item-30192"><a href="https://iwf.sport/anti-doping/tue/">TUEs</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30196" id="menu-item-30196"><a href="https://iwf.sport/anti-doping/sanctions/">Sanctions</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30200" id="menu-item-30200"><a href="https://iwf.sport/anti-doping/reanalysis/">Reanalysis</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-35461" id="menu-item-35461"><a href="https://iwf.sport/anti-doping/education/">Education</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30204" id="menu-item-30204"><a href="https://iwf.sport/anti-doping/ita/">International Testing Agency (ITA)</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30207" id="menu-item-30207"><a href="https://iwf.sport/anti-doping/rules-documents/">Rules &amp; Documents</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30210" id="menu-item-30210"><a href="https://iwf.sport/anti-doping/report-doping/">Report Doping</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="header">
# <div class="pre__menu">
# <div class="container">
# <div class="social menu__not__showed showed">
# <div class="search">
# <div class="icon__search">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-search.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-search@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-search@3x.png 3x"/>
# </div>
# <div class="form__search">
# <form action="https://iwf.sport/" id="searchform" method="get">
# <input id="s" name="s" placeholder="Search..." type="text" value=""/>
# <input type="submit" value=""/>
# </form> </div>
# </div>
# <div class="items__social">
# <a class="item__social" href="https://www.youtube.com/user/IWFmedia" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://twitter.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.facebook.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.instagram.com/iwfnet/" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@3x.png 3x"/>
# </a>
# </div>
# </div>
# <div class="logo">
# <a href="https://iwf.sport">
# <img class="img__logo menu__not__showed showed" src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/iwf-logo.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/iwf-logo@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/iwf-logo@3x.png 3x"/>
# <img class="img__logo menu__showed" src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/iwf-logo-vertical.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/iwf-logo-vertical@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/iwf-logo-vertical@3x.png 3x"/>
# </a>
# </div>
# </div>
# </div>
# <div class="menu" id="menu__desktop">
# <div class="links">
# <div class="container">
# <a class="logo__link" href="https://iwf.sport">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/iwf-logo.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/iwf-logo@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/iwf-logo@3x.png 3x"/>
# </a>
# <a id="menu-button"><img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-menu.png" title="Menú"/></a>
# <a class="link__menu" data-target="about">
# <span class="number">01 </span>
# IWF/Weightlifting </a>
# <a class="link__menu" data-target="news">
# <span class="number">02 </span>
# News and media </a>
# <a class="link__menu" data-target="events">
# <span class="number">03 </span>
# Events </a>
# <a class="link__menu" data-target="results">
# <span class="number">04 </span>
# Results </a>
# <a class="link__menu" data-target="antidoping">
# <span class="number">05 </span>
# Anti-doping </a>
# </div>
# </div>
# <div class="items__menu" id="desktop__menu">
# <div class="single__menu menu__results">
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-103 current_page_item menu-item-30114"><a aria-current="page" href="https://iwf.sport/results/results-by-events/"><div class="container">Results by Events</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30117"><a href="https://iwf.sport/results/ranking-list/"><div class="container">Ranking list</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30126"><a href="https://iwf.sport/results/world-records/"><div class="container">World records</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30131"><a href="https://iwf.sport/results/robi-points/"><div class="container">Robi Points</div></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-30116"><a><div class="container">Old Bodyweight Categories<span class="submenu__arrow">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/menu-arrow.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/menu-arrow@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/menu-arrow@3x.png 3x"/>
# </span></div></a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30113"><a href="https://iwf.sport/results/results-by-events/results-by-events-old-bw/"><div class="container">Results By Events</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30122"><a href="https://iwf.sport/results/ranking-list/ranking-list-old-bw/"><div class="container">Ranking List</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30125"><a href="https://iwf.sport/results/world-records/world-records-old-bw/"><div class="container">World Records</div></a></li>
# </ul>
# </li>
# <div class="footer__menu">
# <div class="container">
# <div class="left">
# <div class="items__social">
# <a class="item__social" href="https://www.youtube.com/user/IWFmedia" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://twitter.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.facebook.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.instagram.com/iwfnet/" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@3x.png 3x"/>
# </a>
# </div>
# <div class="close__menu">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close@3x.png 3x"/>
# Close
# </div>
# </div>
# </div>
# </div> </div>
# <div class="single__menu menu__events">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30096"><a href="https://iwf.sport/events/calendar/"><div class="container">Calendar</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30103"><a href="https://iwf.sport/events/world-championships/"><div class="container">World Championships</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30105"><a href="https://iwf.sport/events/olympic-games/"><div class="container">Olympic Games</div></a></li>
# <div class="footer__menu">
# <div class="container">
# <div class="left">
# <div class="items__social">
# <a class="item__social" href="https://www.youtube.com/user/IWFmedia" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://twitter.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.facebook.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.instagram.com/iwfnet/" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@3x.png 3x"/>
# </a>
# </div>
# <div class="close__menu">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close@3x.png 3x"/>
# Close
# </div>
# </div>
# </div>
# </div> </div>
# <div class="single__menu menu__about">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-35905"><a href="https://iwf.sport/weightlifting_/aboutus/"><div class="container">About Us</div></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-30141"><a><div class="container">How To<span class="submenu__arrow">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/menu-arrow.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/menu-arrow@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/menu-arrow@3x.png 3x"/>
# </span></div></a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30140"><a href="https://iwf.sport/weightlifting_/participants/"><div class="container">Participants</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30142"><a href="https://iwf.sport/weightlifting_/the-two-lifts/"><div class="container">The Two Lifts</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30143"><a href="https://iwf.sport/weightlifting_/competition-flow/"><div class="container">Competition flow</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30144"><a href="https://iwf.sport/weightlifting_/equipment/"><div class="container">Equipment</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30145"><a href="https://iwf.sport/weightlifting_/loading/"><div class="container">Loading</div></a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30148"><a href="https://iwf.sport/weightlifting_/rules/"><div class="container">Rules</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30152"><a href="https://iwf.sport/weightlifting_/athletes-bios/"><div class="container">Athletes / Bios</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30153"><a href="https://iwf.sport/weightlifting_/history/"><div class="container">History</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30169"><a href="https://iwf.sport/weightlifting_/hall-of-fame/"><div class="container">Hall of Fame</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30185"><a href="https://iwf.sport/weightlifting_/licenses/"><div class="container">Licenses</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30188"><a href="https://iwf.sport/weightlifting_/development/"><div class="container">Development</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-36341"><a href="https://iwf.sport/safeguarding-athletes/"><div class="container">Safeguarding Athletes</div></a></li>
# <div class="footer__menu">
# <div class="container">
# <div class="left">
# <div class="items__social">
# <a class="item__social" href="https://www.youtube.com/user/IWFmedia" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://twitter.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.facebook.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.instagram.com/iwfnet/" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@3x.png 3x"/>
# </a>
# </div>
# <div class="close__menu">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close@3x.png 3x"/>
# Close
# </div>
# </div>
# </div>
# </div> </div>
# <div class="single__menu menu__news">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30086"><a href="https://iwf.sport/news-and-media/news/"><div class="container">News</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30071"><a href="https://iwf.sport/weightlifting_/world-weightlifting-magazine/"><div class="container">World Weightlifting Magazine</div></a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-30087"><a href="https://iwf.sport/category/interviews/"><div class="container">Interviews</div></a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-30088"><a href="https://iwf.sport/category/anti-doping-news/"><div class="container">Anti-doping news</div></a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-30089"><a href="https://iwf.sport/category/press-release/"><div class="container">Press Release</div></a></li>
# <div class="footer__menu">
# <div class="container">
# <div class="left">
# <div class="items__social">
# <a class="item__social" href="https://www.youtube.com/user/IWFmedia" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://twitter.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.facebook.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.instagram.com/iwfnet/" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@3x.png 3x"/>
# </a>
# </div>
# <div class="close__menu">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close@3x.png 3x"/>
# Close
# </div>
# </div>
# </div>
# </div> </div>
# <div class="single__menu menu__antidoping">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-35419"><a href="https://iwf.sport/anti-doping/report-doping-2/"><div class="container">Introduction to anti-doping</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-35430"><a href="https://iwf.sport/anti-doping/reanalysis-2/"><div class="container">Doping Control</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-35438"><a href="https://iwf.sport/anti-doping/consequences-of-doping/"><div class="container">Consequences of Doping</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30189"><a href="https://iwf.sport/anti-doping/whereabouts-irtp/"><div class="container">IRTP / Whereabouts</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30192"><a href="https://iwf.sport/anti-doping/tue/"><div class="container">TUEs</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30196"><a href="https://iwf.sport/anti-doping/sanctions/"><div class="container">Sanctions</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30200"><a href="https://iwf.sport/anti-doping/reanalysis/"><div class="container">Reanalysis</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-35461"><a href="https://iwf.sport/anti-doping/education/"><div class="container">Education</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30204"><a href="https://iwf.sport/anti-doping/ita/"><div class="container">International Testing Agency (ITA)</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30207"><a href="https://iwf.sport/anti-doping/rules-documents/"><div class="container">Rules &amp; Documents</div></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30210"><a href="https://iwf.sport/anti-doping/report-doping/"><div class="container">Report Doping</div></a></li>
# <div class="footer__menu">
# <div class="container">
# <div class="left">
# <div class="items__social">
# <a class="item__social" href="https://www.youtube.com/user/IWFmedia" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://twitter.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.facebook.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.instagram.com/iwfnet/" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@3x.png 3x"/>
# </a>
# </div>
# <div class="close__menu">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/icon-close@3x.png 3x"/>
# Close
# </div>
# </div>
# </div>
# </div> </div>
# </div>
# </div>
# </div>
# <div class="page__blocker close__menu"></div>
# <script>
#             jQuery(document).ready(function( $ ) {
#                         $("#mobile__menu").mmenu({
#                         extensions:["position-front", "position-right"],
#                             "navbars": [
#                         {
#                         "position": "bottom",
#                         "content": [
#                             "",
#                             '<div class="items__social"><a href="https://www.youtube.com/user/IWFmedia" class="item__social"><img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@3x.png 3x"></a><a href="https://twitter.com/iwfnet" class="item__social"><img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@3x.png 3x"></a><a href="https://www.facebook.com/iwfnet" class="item__social"><img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@3x.png 3x"></a><a href="https://www.instagram.com/iwfnet/" target="_blank" class="item__social"><img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@3x.png 3x"></a></div>'
#                             ]
#                         }
#                     ]
#                         }, {
#                     // configuration
#                     offCanvas: {
#                         pageSelector: "#Wrapper"
#                     }
#                     });
#
#
#                 var API = $("#mobile__menu").data( "mmenu" );
#
#                 $(".close-button-menu").click(function() {
#                     API.close();
#                     });
#                 $("#menu-button").click(function() {
#                     API.open();
#                 });
#
#             $('#loading').fadeOut();
#             });
#         </script>
# <div id="page__container">
# <div class="header_page">
# <div class="container">
# <p class="parent">Results</p>
# <h1>Results by Events </h1>
# </div>
# </div>
# <section class="results_by_events">
# <div class="filters">
# <div class="title__filters">
# <div class="container">
# <div class="row">
# <div class="col-12">
# <h2></h2>
# </div>
# </div>
# </div>
# </div>
# <div class="filters__container">
# <div class="container">
# <div class="row">
# <div class="col-md-4">
# <div class="search__form">
# <div class="row">
# <div class="col-12">
# <div class="filter_title">Year Search</div>
# </div>
# </div>
# <div class="row">
# <div class="col-12">
# <form action="" method="get">
# <div class="form__group">
# <select name="event_year">
# <option selected="selected" value="2022">2022</option><option value="2021">2021</option><option value="2020">2020</option><option value="2019">2019</option><option value="2018">2018</option> </select>
# </div>
# <div class="form__group">
# <a class="submit__form more__link link__circle link__circle__white">Search</a>
# <input type="submit" value="Search"/>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4">
# <div class="search__form">
# <div class="row">
# <div class="col-12">
# <div class="filter_title">Event Search</div>
# </div>
# </div>
# <div class="row">
# <div class="col-12">
# <form action="" method="get">
# <div class="form__group">
# <select name="event_type">
# <option value="all">Filter by EVENT TYPE</option>
# <option value="Continental Championships">Continental Championships</option><option value="Continental Champioships">Continental Champioships</option><option value="Continental Games">Continental Games</option><option value="Grand Prix">Grand Prix</option><option value="Olympic Games">Olympic Games</option><option value="Other">Other</option><option value="Others">Others</option><option value="Regional Championships">Regional Championships</option><option value="Regional Games">Regional Games</option><option value="Universiade">Universiade</option><option value="World Championships">World Championships</option><option value="World University Championships">World University Championships</option> </select>
# </div>
# <div class="form__group">
# <select name="event_age">
# <option value="all">Filter by AGE GROUP</option>
# <option value="Youth">Youth</option>
# <option value="Junior">Junior</option>
# <option value="Senior">Senior</option> </select>
# </div>
# <div class="form__group">
# <select name="event_nation">
# <option value="all">Filter by NATION</option>
# <option value="ALB">ALB</option><option value="ALG">ALG</option><option value="ARG">ARG</option><option value="AUS">AUS</option><option value="AUT">AUT</option><option value="AZE">AZE</option><option value="BLR">BLR</option><option value="BOL">BOL</option><option value="BOT">BOT</option><option value="BRA">BRA</option><option value="BUL">BUL</option><option value="CAN">CAN</option><option value="CGO">CGO</option><option value="CHI">CHI</option><option value="CHN">CHN</option><option value="CMR">CMR</option><option value="COK">COK</option><option value="COL">COL</option><option value="CRO">CRO</option><option value="CUB">CUB</option><option value="CYP">CYP</option><option value="CZE">CZE</option><option value="DOM">DOM</option><option value="ECU">ECU</option><option value="EGY">EGY</option><option value="ESA">ESA</option><option value="ESP">ESP</option><option value="EST">EST</option><option value="FIJ">FIJ</option><option value="FIN">FIN</option><option value="FRA">FRA</option><option value="FSM">FSM</option><option value="GBR">GBR</option><option value="GEO">GEO</option><option value="GER">GER</option><option value="GRE">GRE</option><option value="GUA">GUA</option><option value="HKG">HKG</option><option value="INA">INA</option><option value="IND">IND</option><option value="IRI">IRI</option><option value="ISR">ISR</option><option value="ITA">ITA</option><option value="JPN">JPN</option><option value="KAZ">KAZ</option><option value="KEN">KEN</option><option value="KGZ">KGZ</option><option value="KOR">KOR</option><option value="KOS">KOS</option><option value="KSA">KSA</option><option value="LAO">LAO</option><option value="LBA">LBA</option><option value="LTU">LTU</option><option value="MAD">MAD</option><option value="MAR">MAR</option><option value="MAS">MAS</option><option value="MEX">MEX</option><option value="MLT">MLT</option><option value="MRI">MRI</option><option value="MYA">MYA</option><option value="NCL">NCL</option><option value="NEP">NEP</option><option value="NOR">NOR</option><option value="NZL">NZL</option><option value="OWF">OWF</option><option value="PER">PER</option><option value="PHI">PHI</option><option value="PNG">PNG</option><option value="POL">POL</option><option value="PRK">PRK</option><option value="PUR">PUR</option><option value="QAT">QAT</option><option value="ROU">ROU</option><option value="RSA">RSA</option><option value="RUS">RUS</option><option value="SAM">SAM</option><option value="SIN">SIN</option><option value="SMR">SMR</option><option value="SRB">SRB</option><option value="SUI">SUI</option><option value="SVK">SVK</option><option value="SWE">SWE</option><option value="THA">THA</option><option value="TKM">TKM</option><option value="TPE">TPE</option><option value="TUN">TUN</option><option value="TUR">TUR</option><option value="UAE">UAE</option><option value="UGA">UGA</option><option value="USA">USA</option><option value="UZB">UZB</option><option value="VEN">VEN</option><option value="WAF">WAF</option> </select>
# </div>
# <div class="form__group">
# <a class="submit__form more__link link__circle link__circle__white">Search</a>
# <input type="submit" value="Search"/>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4">
# <div class="search__form">
# <div class="row">
# <div class="col-12">
# <div class="filter_title">Athletes Search</div>
# </div>
# </div>
# <div class="row">
# <div class="col-12">
# <form action="" method="get">
# <div class="form__group">
# <input id="athlete_name" name="athlete_name" placeholder="NAME (or FRAGMENT)" type="text" value=""/>
# </div>
# <div class="form__group">
# <select name="athlete_gender">
# <option value="all">Filter by GENDER</option>
# <option value="M">Man</option>
# <option value="W">Woman</option> </select>
# </div>
# <div class="form__group">
# <select name="athlete_nation">
# <option value="all">Filter by NATION</option>
# ...
# </p>
# </div>
# <div class="col-md-2 moreinfo col-4 not__cell__767">
# <span class="link__circle link__circle__pink">More info</span>
# </div>
# </div>
# </div>
# <div class="see_more_mobile"></div>
# </a>
# <a class="card" href="?event_id=513">
# <div class="container">
# <div class="row">
# <div class="col-md-5 col-12 not__cell__767__full">
# <p class="title"><span class="text">2021 South-American Championships</span></p>
# </div>
# <div class="col-md-2 col-4 not__cell__767">
# <p class="normal__text">
# May 10, 2021 </p>
# <div class="separator"></div>
# </div>
# <div class="col-md-3 col-4 not__cell__767">
# <p class="normal__text">
# <span class="flag"><img alt="COL" src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/flags/COL.png"/></span>
# Cali, <strong>COL</strong>
# </p>
# </div>
# <div class="col-md-2 moreinfo col-4 not__cell__767">
# <span class="link__circle link__circle__pink">More info</span>
# </div>
# </div>
# </div>
# <div class="see_more_mobile"></div>
# </a>
# <a class="card" href="?event_id=514">
# <div class="container">
# <div class="row">
# <div class="col-md-5 col-12 not__cell__767__full">
# <p class="title"><span class="text">2021 Ibero-American Championships</span></p>
# </div>
# <div class="col-md-2 col-4 not__cell__767">
# <p class="normal__text">
# May 10, 2021 </p>
# <div class="separator"></div>
# </div>
# <div class="col-md-3 col-4 not__cell__767">
# <p class="normal__text">
# <span class="flag"><img alt="COL" src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/flags/COL.png"/></span>
# Cali, <strong>COL</strong>
# </p>
# </div>
# <div class="col-md-2 moreinfo col-4 not__cell__767">
# <span class="link__circle link__circle__pink">More info</span>
# </div>
# </div>
# </div>
# <div class="see_more_mobile"></div>
# </a>
# <a class="card" href="?event_id=515">
# <div class="container">
# <div class="row">
# <div class="col-md-5 col-12 not__cell__767__full">
# <p class="title"><span class="text">2021 Open Championships</span></p>
# </div>
# <div class="col-md-2 col-4 not__cell__767">
# <p class="normal__text">
# May 10, 2021 </p>
# <div class="separator"></div>
# </div>
# <div class="col-md-3 col-4 not__cell__767">
# <p class="normal__text">
# <span class="flag"><img alt="COL" src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/flags/COL.png"/></span>
# Cali, <strong>COL</strong>
# </p>
# </div>
# <div class="col-md-2 moreinfo col-4 not__cell__767">
# <span class="link__circle link__circle__pink">More info</span>
# </div>
# </div>
# </div>
# <div class="see_more_mobile"></div>
# </a>
# <a class="card" href="?event_id=510">
# <div class="container">
# <div class="row">
# <div class="col-md-5 col-12 not__cell__767__full">
# <p class="title"><span class="text">2020 Pan-American Championships</span></p>
# </div>
# <div class="col-md-2 col-4 not__cell__767">
# <p class="normal__text">
# Apr 18, 2021 </p>
# <div class="separator"></div>
# </div>
# <div class="col-md-3 col-4 not__cell__767">
# <p class="normal__text">
# <span class="flag"><img alt="DOM" src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/flags/DOM.png"/></span>
# Santo Domingo, <strong>DOM</strong>
# </p>
# </div>
# <div class="col-md-2 moreinfo col-4 not__cell__767">
# <span class="link__circle link__circle__pink">More info</span>
# </div>
# </div>
# </div>
# <div class="see_more_mobile"></div>
# </a>
# <a class="card" href="?event_id=509">
# <div class="container">
# <div class="row">
# <div class="col-md-5 col-12 not__cell__767__full">
# <p class="title"><span class="text">2020 Asian Championships</span></p>
# </div>
# <div class="col-md-2 col-4 not__cell__767">
# <p class="normal__text">
# Apr 17, 2021 </p>
# <div class="separator"></div>
# </div>
# <div class="col-md-3 col-4 not__cell__767">
# <p class="normal__text">
# <span class="flag"><img alt="UZB" src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/flags/UZB.png"/></span>
# Tashkent, <strong>UZB</strong>
# </p>
# </div>
# <div class="col-md-2 moreinfo col-4 not__cell__767">
# <span class="link__circle link__circle__pink">More info</span>
# </div>
# </div>
# </div>
# <div class="see_more_mobile"></div>
# </a>
# <a class="card" href="?event_id=508">
# <div class="container">
# <div class="row">
# <div class="col-md-5 col-12 not__cell__767__full">
# <p class="title"><span class="text">European Championships</span></p>
# </div>
# <div class="col-md-2 col-4 not__cell__767">
# <p class="normal__text">
# Apr 03, 2021 </p>
# <div class="separator"></div>
# </div>
# <div class="col-md-3 col-4 not__cell__767">
# <p class="normal__text">
# <span class="flag"><img alt="RUS" src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/flags/RUS.png"/></span>
# Moscow, <strong>RUS</strong>
# </p>
# </div>
# <div class="col-md-2 moreinfo col-4 not__cell__767">
# <span class="link__circle link__circle__pink">More info</span>
# </div>
# </div>
# </div>
# <div class="see_more_mobile"></div>
# </a>
# </div>
# </div>
# <a class="see__other" href="https://iwf.sport/results/results-by-events/results-by-events-old-bw/">CLICK HERE TO SEE RESULTS BY EVENTS FROM OLD BODYWEIGHT CATEGORIES</a>
# </div>
# </section>
# </div>
# <script id="contact-form-7-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/iwf.sport\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"}};
# /* ]]> */
# </script>
# <script id="contact-form-7-js" src="https://iwf.sport/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.2.2" type="text/javascript"></script>
# <script id="google-recaptcha-js" src="https://www.google.com/recaptcha/api.js?render=6LcxGugcAAAAAB2gfpXg4VFjXh6sCLeKwhvQOMsh&amp;ver=3.0" type="text/javascript"></script>
# <script id="wpcf7-recaptcha-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var wpcf7_recaptcha = {"sitekey":"6LcxGugcAAAAAB2gfpXg4VFjXh6sCLeKwhvQOMsh","actions":{"homepage":"homepage","contactform":"contactform"}};
# /* ]]> */
# </script>
# <script id="wpcf7-recaptcha-js" src="https://iwf.sport/wp-content/plugins/contact-form-7/modules/recaptcha/script.js?ver=5.2.2" type="text/javascript"></script>
# <script id="vc_vendor_jwplayer-js" src="https://iwf.sport/wp-content/plugins/js_composer/assets/js/frontend_editor/vendors/plugins/jwplayer.js?ver=1.0" type="text/javascript"></script>
# <script id="mmenuscript-js" src="https://iwf.sport/wp-content/themes/iwf2019/lib/mmenu/dist/jquery.mmenu.all.js?ver=1.0.0" type="text/javascript"></script>
# <script id="javascript-js" src="https://iwf.sport/wp-content/themes/iwf2019/assets/javascript/javascript.js?ver=7.5" type="text/javascript"></script>
# <div class="prefooter">
# <div class="partners">
# <div class="container">
# <div class="swiper-partners">
# <div class="swiper-wrapper">
# <div class="swiper-slide">
# <a class="logo" href="https://www.roguefitness.com/" target="_blank">
# <img alt="Rogue Fitness" src="https://iwf.sport/wp-content/uploads/2020/09/Rogue.jpg" title="Rogue Fitness"/>
# </a>
# </div>
# <div class="swiper-slide">
# <a class="logo" href="http://en.zhangkong.com/" target="_blank">
# <img alt="Zhangkong Barbell Manufacturing Co. Ltd." src="https://iwf.sport/wp-content/uploads/2020/09/zkc_new.jpg" title="Zhangkong Barbell Manufacturing Co. Ltd."/>
# </a>
# </div>
# <div class="swiper-slide">
# <a class="logo" href="http://www.werk-sansport.com/" target="_blank">
# <img alt="Werk-San" src="https://iwf.sport/wp-content/uploads/2020/09/werk-san.jpg" title="Werk-San"/>
# </a>
# </div>
# <div class="swiper-slide">
# <a class="logo" href="https://www.uesakabarbell.com/" target="_blank">
# <img alt="Uesaka Barbell Company" src="https://iwf.sport/wp-content/uploads/2020/09/uesaka_logo_600.jpg" title="Uesaka Barbell Company"/>
# </a>
# </div>
# <div class="swiper-slide">
# <a class="logo" href="https://www.eleiko.com/" target="_blank">
# <img alt="Eleiko Group AB" src="https://iwf.sport/wp-content/uploads/2020/09/Eleiko_Logo_2020.png" title="Eleiko Group AB"/>
# </a>
# </div>
# <div class="swiper-slide">
# <a class="logo" href="http://en.dhs-sports.com/" target="_blank">
# <img alt="Shanghai Double Happiness Co. Ltd." src="https://iwf.sport/wp-content/uploads/2020/09/dhs.jpg" title="Shanghai Double Happiness Co. Ltd."/>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="prefooter__img">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/home/weight-prefooter.jpg"/>
# </div>
# </div>
# <footer> <img class="footer__bg" src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/bg-footer.jpg"/>
# <div class="container">
# <div class="row">
# <div class="col-lg-3">
# <div class="row">
# <div class="col-lg-12 col-md-6">
# <p class="footer__title">IWF Headquarters</p>
# <p>Maison du Sport International</p>
# <p>Av. de Rhodanie 54</p>
# <p>Switzerland-1007, Lausanne</p>
# <p>Tel: +41-216013227</p>
# <div class="spacer"></div>
# </div>
# </div>
# </div>
# <div class="col-lg-6">
# <div class="row menu">
# <div class="col-md-6">
# <p><a href="https://iwf.sport/focus-on-iwf/executive-board/" target="">Executive Board</a></p>
# <p><a href="https://iwf.sport/focus-on-iwf/committees/" target="">Committees</a></p>
# <p><a href="https://iwf.sport/focus-on-iwf/commissions/" target="">Commissions</a></p>
# <p><a href="https://iwf.sport/focus-on-iwf/federations/" target="">Member Federations</a></p>
# <p><a href="https://iwf.sport/weightlifting_/technical_officials/" target="">Technical Officials</a></p>
# </div>
# <div class="col-md-6">
# <p><a href="https://iwf.sport/focus-on-iwf/secretariat/" target="">Secretariat</a></p>
# <p><a href="https://media.iwf.net/search/results#/?query=&amp;type=flex" target="">Image Gallery</a></p>
# <p><a href="https://www.dartfish.tv/ChannelHome?CR=p140760" target="">Video Gallery</a></p>
# <p><a href="https://iwf.sport/downloads/" target="">Download center</a></p>
# </div>
# </div>
# <div class="spacer"></div>
# </div>
# <div class="col-lg-3">
# <p class="footer__title">Follow us</p>
# <div class="items__social">
# <a class="item__social" href="https://www.youtube.com/user/IWFmedia" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/youtube-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://twitter.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/twitter-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.facebook.com/iwfnet" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/facebook-white@3x.png 3x"/>
# </a>
# <a class="item__social" href="https://www.instagram.com/iwfnet/" target="_blank">
# <img src="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white.png" srcset="https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@2x.png 2x, https://iwf.sport/wp-content/themes/iwf2019/assets/images/instagram-white@3x.png 3x"/>
# </a>
# </div>
# <p><a href="https://iwf.sport/wp-content/uploads/2021/07/IWF-PRIVACY-POLICY.pdf">Privacy Policy</a></p>
# <p><a href="https://iwf.sport/wp-content/uploads/2021/07/IWF-CPolicy.pdf">Cookies Policy</a></p>
# <div class="spacer"></div>
# </div>
# </div>
# </div>
# <div class="sub__footer">
# <p>Copyright 2020 - International Weightlifting Federation</p>
# </div>
# </footer>
# <script src="https://iwf.sport/wp-content/themes/iwf2019/assets/javascript/vendor/swiper.min.js"></script>
# <script>
#             var swiper = new Swiper('.swiper-events', {
#                 pagination: {
#                     el: '.top-pagination',
#                     clickable: true
#                 },
#                 paginationClickable: true,
#                 spaceBetween: 0,
#                 loop: true,
#                 autoplay: {
#                     delay: 9000,
#                     disableOnInteraction: false,
#                 },
#                 breakpoints: {
#                     991: {
#                         autoplay:false
#                     }
#                 }
#
#
#             });
#             jQuery(".swiper-button-pause").click(function(){
#                 swiper.autoplay.stop();
#                 jQuery(".swiper-button-pause").removeClass("showed");
#                 jQuery(".swiper-button-play").addClass("showed");
#             });
#
#             jQuery(".swiper-button-play").click(function(){
#                 swiper.autoplay.start();
#                 jQuery(".swiper-button-play").removeClass("showed");
#                 jQuery(".swiper-button-pause").addClass("showed");
#             });
#             swiper.on('slideChange', function () {
#                 setTimeout(function(){
#                     var id = jQuery(".swiper-slide-active").data("slide-id");
#                     var logo_id = "#event-logo-"+id;
#                     var documents_id = "#event-links-"+id;
#                     var data_id = "#date-container-"+id;
#
#                     jQuery(".event-logo").removeClass("showed");
#                     jQuery(".event-links").removeClass("showed");
#                     jQuery(".date__container").removeClass("showed");
#
#                     jQuery(logo_id).addClass("showed");
#                     jQuery(documents_id).addClass("showed");
#                     jQuery(data_id).addClass("showed");
#                  }, 300);
#             });
#
#             jQuery(document).ready(function(){
#                 var id = jQuery(".swiper-slide-active").data("slide-id");
#                 var logo_id = "#event-logo-"+id;
#                 var documents_id = "#event-links-"+id;
#                 var data_id = "#date-container-"+id;
#                 jQuery(".event-logo").removeClass("showed");
#                 jQuery(".event-links").removeClass("showed");
#                 jQuery(".date__container").removeClass("showed");
#                 jQuery(logo_id).addClass("showed");
#                 jQuery(documents_id).addClass("showed");
#                 jQuery(data_id).addClass("showed");
#             });
#
#             var swiperupcoming = new Swiper('.swiper-upcoming', {
#                 pagination: {
#                     el: '.upcoming-pagination',
#                     clickable: true
#                 },
#                 spaceBetween: 0,
#                 speed: 1000,
#                 slidesPerView: 3,
#                 slidesPerGroup: 1,
#                 loop: true,
#                 autoplay: {
#                     delay: 3000,
#                     disableOnInteraction: false,
#                 },
#                 breakpoints: {
#                     991: {
#                         slidesPerView: 2,
#                         slidesPerGroup: 1,
#                     },
#                     560: {
#                         slidesPerView: 1,
#                         slidesPerGroup: 1,
#                     }
#                 }
#             });
#             var swiperpartners = new Swiper('.swiper-partners', {
#                 spaceBetween: 0,
#                 slidesPerView: 4,
#                 slidesPerGroup: 1,
#                 loop: true,
#                 autoplay: {
#                     delay: 3000,
#                     disableOnInteraction: false,
#                 },
#                 breakpoints: {
#                     900: {
#                         slidesPerView: 2,
#                         slidesPerGroup: 1,
#                     },
#                     767: {
#                         slidesPerView: 2,
#                         slidesPerGroup: 1,
#                     },
#                     560: {
#                         slidesPerView: 1,
#                         slidesPerGroup: 1,
#                     }
#                 }
#             });
#         </script>
# </body>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#
#  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-47296698-1', 'iwf.net');
#   ga('send', 'pageview');
# </script>
# </html>

# %%
# def _scrapOptionYears():
#
#
# return option_

# div_select = _loadNewBodyweightEventsPage().findAll("div", {"class": "form__group"})

# %%
select_option = _loadNewBodyweightEventsPage().findAll("select", {"name": "event_year"})[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 select_option = _loadNewBodyweightEventsPage().findAll("select", {"name": "event_year"})[0]
#
# NameError: name '_loadNewBodyweightEventsPage' is not defined

# %%
print(select_option)

# %%
options = select_option.findAll("option")
print(options)

# %%
years = []
for item in options:
    #print(item.get_text())
    years.append(item.get_text())
print(years)

# %%
old = core._loadOldBodyweightEventsPage()

# %%
print(old)

# %%
core.getYears()
# Out:
# ['2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '1999',
#  '1998']

# %%
print(core.getYears())
# Out:
# ['2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998']
